# %% [markdown]
# ## The Restaurantour - Ratings Adjustment
#
# Use Bayesian Smoothing to adjust restaurant ratings based on clustering

# %%
import pickle
fpath = 'drlaurenmac/the-restaurantour/data-wrangling/datasets/'

#load clusters:
with open(fpath + 'clusters_dict.pkl','rb') as f:
    clusters_dict = pickle.load(f)

#load restaurant info:
with open(fpath + 'df_rests_all.pkl','rb') as f:
    df_rests_all = pickle.load(f)

# %%
df_rests_all.head()
# Out:
#                   yelp_id                    fsq_id  \
# 0  Iue8gacs66BJeFRG83RLEA  593e7324e7a23754a3d8e6fd
# 1  B8MrNvNvvCtRVx4VqypLOQ  4f45397e19836ed0019960dc
# 2  -YE-UnethM8jbYFWl9ktRQ  6057e66e84fc74200d24489e
# 3  Mj2BC82wH_oy1YC9PanJXw  15cff4ee744c4f0870ec98b4
# 4  Tr4E7gyf2UUNkk3piQFdGg  619ac68726c0a15634e46af4
#
#                       yelp_name                      fsq_name  \
# 0            Halal Kitchen Cafe            Halal Kitchen Cafe
# 1           Nan Dagh Kabob Dagh           Nan Dagh Kabob Dagh
# 2             Flavors From Afar             Flavors From Afar
# 3      Mama D's African Cuisine      Mama D's African Cuisine
# 4  Jaliz Cuisine of East Africa  Jaliz Cuisine of East Africa
#
#                     yelp_categories  \
# 0   [Halal, Middle Eastern, Afghan]
# 1                   [Halal, Afghan]
# 2  [Middle Eastern, Halal, African]
# 3                         [African]
# 4                         [African]
#
#                                       fsq_categories     neighborhood  \
# 0                                       [Restaurant]     [Northridge]
# 1  [Pizzeria, Mediterranean Restaurant, Middle Ea...         [Reseda]
# 2  [African Restaurant, Middle Eastern Restaurant...   [Mid-Wilshire]
# 3                               [African Restaurant]  [Boyle Heights]
# 4                  [Coffee Shop, African Restaurant]       [Van Nuys]
#
#     latitude   longitude     census_block  ... fsq_popularity fsq_price  \
# 0  34.228354 -118.528353  060371154031000  ...       0.922282         2
# 1  34.200769 -118.527648  060371323012000  ...       0.409895         1
# 2  34.056837 -118.364192  060372169022000  ...       0.913157       NaN
# 3  34.026788 -118.219327  060372051102000  ...            NaN       NaN
# 4   34.19105 -118.454684  060371278053004  ...       0.916832         2
#
#   fsq_rating fsq_total_photos fsq_total_ratings fsq_total_tips fsq_tastes  \
# 0        NaN              NaN               NaN            NaN        NaN
# 1        NaN              NaN               NaN            NaN        NaN
# 2        NaN              NaN               NaN            NaN        NaN
# 3        NaN              NaN               NaN            NaN        NaN
# 4        NaN              NaN               NaN            NaN        NaN
#
#                                         fsq_features  \
# 0                 [{'services': {'delivery': True}}]
# 1                                                NaN
# 2  [{'food_and_drink': {'meals': {'lunch': True, ...
# 3                                                NaN
# 4  [{'payment': {'credit_cards': {'accepts_credit...
#
#                          website formatted_address
# 0         http://www.halalkc.com               NaN
# 1   http://naan-persian.keeq.io/               NaN
# 2  http://www.flavorsfromafar.co               NaN
# 3    https://www.mamadsfood.com/               NaN
# 4    http://www.jalizcuisine.com               NaN
#
# [5 rows x 38 columns]

# %%
#choose a subset of the columns:
rest_cols = [
    'yelp_id',
    'yelp_name',
    'yelp_categories',
    'neighborhood',
    'latitude',
    'longitude',
    'display_address',
    'display_phone',
    'is_chain',
    'yelp_is_claimed',
    'yelp_price',
    'yelp_rating',
    'yelp_review_count',
    'fsq_popularity',
    'fsq_price',
    'fsq_rating',
    'fsq_total_photos',
    'fsq_total_ratings',
    'fsq_total_tips',
    'website'
]

# %%
df_rests = df_rests_all[rest_cols]
df_rests.shape
# Out:
# (22201, 20)

# %%
#remove restaurants without a neighborhood:
df_rests = df_rests.assign(neighborhood_rem = df_rests['neighborhood'].apply(lambda x: x if len(x) > 0 else float('NaN')))
df_rests = df_rests.loc[df_rests['neighborhood_rem'].notna(),rest_cols]
df_rests.shape
# Out:
# (20312, 20)

# %%
#remove restaurants that are not claimed on yelp:
df_rests = df_rests[df_rests['yelp_is_claimed'] == True]
df_rests.shape
# Out:
# (17221, 20)

# %%
#select only restaurants with >= 4.0 yelp rating
df_rests_selected = df_rests.query('yelp_rating >= 4.0')
df_rests_selected.shape
# Out:
# (10168, 20)

# %%
#remove chain restaurants:
df_rests_selected = df_rests_selected[df_rests_selected['is_chain'] != 1]
df_rests_selected.shape
# Out:
# (10013, 20)

# %%
#remove restaurants that do not have at least 20 reviews
df_rests_selected = df_rests_selected.query('yelp_review_count > 20')
df_rests_selected.shape
# Out:
# (8708, 20)

# %%
#create an additional column of a distribution of yelp ratings (since do not have this info):
import numpy as np
df_rests_selected.loc[:,'yelp_rating_dist'] = ''

for ind in df_rests_selected.index:
    ratings = np.random.normal(loc=df_rests_selected.loc[ind,'yelp_rating'],scale=0.5,size=df_rests_selected.loc[ind,'yelp_review_count'])
    thresh_ratings = []
    for rating in ratings:
        if rating > 5:
            thresh_ratings.append(5)
        elif rating < 0:
            thresh_ratings.append(0)
        else:
            thresh_ratings.append(rating)
    df_rests_selected.loc[:,'yelp_rating_dist'].loc[ind] = thresh_ratings

df_rests_selected.head()
# Out:
#                   yelp_id                     yelp_name  \
# 0  Iue8gacs66BJeFRG83RLEA            Halal Kitchen Cafe
# 2  -YE-UnethM8jbYFWl9ktRQ             Flavors From Afar
# 3  Mj2BC82wH_oy1YC9PanJXw      Mama D's African Cuisine
# 4  Tr4E7gyf2UUNkk3piQFdGg  Jaliz Cuisine of East Africa
# 5  u8U8Zc1Se_gY30zNeOTSqg      Moun Of Tunis Restaurant
#
#                     yelp_categories     neighborhood   latitude   longitude  \
# 0   [Halal, Middle Eastern, Afghan]     [Northridge]  34.228354 -118.528353
# 2  [Middle Eastern, Halal, African]   [Mid-Wilshire]  34.056837 -118.364192
# 3                         [African]  [Boyle Heights]  34.026788 -118.219327
# 4                         [African]       [Van Nuys]   34.19105 -118.454684
# 5        [Moroccan, African, Halal]      [Hollywood]  34.098451 -118.352524
#
#                                      display_address   display_phone is_chain  \
# 0  [18112 Parthenia St, Ste B, Northridge, CA 91325]  (818) 886-6106        0
# 2            [1046 S Fairfax, Los Angeles, CA 90019]  (323) 879-9778        0
# 3            [1240 S Soto St, Los Angeles, CA 90023]  (562) 269-9818        0
# 4           [14747 Kittridge St, Van Nuys, CA 91405]  (818) 571-2188        0
# 5    [7445 1/2 W Sunset Blvd, Los Angeles, CA 90046]  (323) 874-3333        0
#
#   yelp_is_claimed  ... yelp_rating yelp_review_count fsq_popularity fsq_price  \
# 0            True  ...         4.0               182       0.922282         2
# 2            True  ...         5.0               113       0.913157       NaN
# 3            True  ...         4.5                57            NaN       NaN
# 4            True  ...         4.5                40       0.916832         2
# 5            True  ...         4.0               294       0.902242         2
#
#   fsq_rating fsq_total_photos fsq_total_ratings fsq_total_tips  \
# 0        NaN              NaN               NaN            NaN
# 2        NaN              NaN               NaN            NaN
# 3        NaN              NaN               NaN            NaN
# 4        NaN              NaN               NaN            NaN
# 5        8.2               26                34             10
#
#                          website  \
# 0         http://www.halalkc.com
# 2  http://www.flavorsfromafar.co
# 3    https://www.mamadsfood.com/
# 4    http://www.jalizcuisine.com
# 5    http://www.mounoftunis.com/
#
#                                     yelp_rating_dist
# 0  [2.9497774452882055, 4.147791424236157, 3.9281...
# 2  [4.370065654437283, 4.812044260796708, 4.10354...
# 3  [4.748355119565722, 4.25590733351322, 5, 4.691...
# 4  [4.371011025338866, 4.1840064065837215, 4.9456...
# 5  [4.286687403425167, 3.977754792037238, 4.13492...
#
# [5 rows x 21 columns]

# %%
#use the clusters_dict to alter the ratings differently in different clusters
#in this version of the cluster dict, 0 = tourist, 1 = trendy, 2 = hipster, 3 = other wealthy, 4 = waterfront, etc
#in less traffic areas, restaurants with a lot of reviews might not be the best (bias towards low quality)
#also, can use price to sort differently. Starting mean is lower for $ and $$$$ priced restaurants
cluster_list = []
for index, row in df_rests_selected.iterrows():
    clusts = []
    for neigh in row['neighborhood']:
        if neigh in clusters_dict['cluster']:
            clusts.append(clusters_dict['cluster'][neigh])
        elif neigh == 'East La Mirada':
            clusts.append(clusters_dict['cluster']['East Whittier'])
        else:
            print(neigh) #check to see which neighborhoods present that are not in clusters
    if clusts:
        cluster_list.append(min(clusts)) #take the min cluster value
    else:
        cluster_list.append(float('NaN'))

df_rests_selected['cluster'] = cluster_list
# Out:
# Universal City
# Griffith Park
# Universal City
# Griffith Park
# Sepulveda Basin
# Sepulveda Basin
# Ramona
# Unincorporated Santa Monica Mountains
# Unincorporated Santa Monica Mountains
# Unincorporated Santa Monica Mountains
# Unincorporated Santa Susana Mountains
# Ramona
# Chatsworth Reservoir
# Lancaster
# Lancaster
# Palmdale
# Unincorporated Santa Susana Mountains
# Castaic Canyons

# %%
#use the clusters to create distributions of the fsq ratings (since so many NaNs)
#calculate the averages before assigning nan ratings to -1
avg_fsq_rating = np.nanmean(list(df_rests_selected['fsq_rating']))
avg_fsq_total_rating = np.nanmean(list(df_rests_selected['fsq_total_ratings']))

rest_clusters = df_rests_selected.groupby('cluster')
avg_fsq_ratings = {}
avg_fsq_total_ratings = {}
for clust, inds in rest_clusters.groups.items():
    avg_fsq_ratings[clust] = np.nanmean(list(df_rests_selected.loc[inds,'fsq_rating']))
    avg_fsq_total_ratings[clust] = np.nanmean(list(df_rests_selected.loc[inds,'fsq_total_ratings']))

#assign nan ratings to -1 (to fix DataSpell glitch when running code below):
df_rests_selected.loc[df_rests_selected['fsq_rating'].isna(),'fsq_rating'] = -1

# %%
#create an additional column of a distribution of yelp ratings:
df_rests_selected.loc[:,'fsq_rating_dist'] = ''

for ind in df_rests_selected.index:
    if df_rests_selected.loc[ind,'fsq_rating'] == -1: #there is no rating, so increase the uncertainty
        clust = df_rests_selected.loc[ind,'cluster']
        if clust >= 0.0:
            ratings = np.random.normal(loc=avg_fsq_ratings[clust],scale=0.4,size=int(np.round(avg_fsq_total_ratings[clust])))
        else:
            ratings = np.random.normal(loc=avg_fsq_rating,scale=0.4,size=int(np.round(avg_fsq_total_rating)))
    else:
        ratings = np.random.normal(loc=df_rests_selected.loc[ind,'fsq_rating'],scale=0.2,size=df_rests_selected.loc[ind,'fsq_total_ratings'])
    thresh_ratings = []
    for rating in ratings:
        if rating > 10:
            thresh_ratings.append(10)
        elif rating < 0:
            thresh_ratings.append(0)
        else:
            thresh_ratings.append(rating)
    df_rests_selected.loc[:,'fsq_rating_dist'].loc[ind] = thresh_ratings

#convert -1 back to NaNs:
df_rests_selected.loc[df_rests_selected['fsq_rating'] == -1,'fsq_rating'] = float('NaN')

# %%
#Bayesian smoothing function
def bayes_sum(x, N=100, mu=3):
    return (np.sum(x) + mu*N) / (len(x) + N)

# %%
#using the price and cluster information, use bayesian smoothing to adjust the restaurants:
#this is a simple version that will be adjusted later (requires more research into clusters)
bayes_ratings_yelp = []
bayes_ratings_fsq = []
for index, row in df_rests_selected.iterrows():
    if row['yelp_price'] == '$' or row['yelp_price'] == '$$$$':
        mu_yelp = 2
        mu_fsq = 4
    else:
        mu_yelp = 3
        mu_fsq = 7

    #add negative bias for cafes and sandwiches (tend to be lunch spots):
    if 'Sandwiches' in row['yelp_categories'] or 'Cafes' in row['yelp_categories']:
        mu_yelp -= 1
        mu_fsq -= 1

    if row['cluster'] < 4: #restaurant hotspots have more reviews
        N_yelp = 50
        N_fsq = 25 #bias towards places with less fsq reviews
    else:
        N_yelp = 25
        N_fsq = 10
    bayes_ratings_yelp.append(bayes_sum(row['yelp_rating_dist'], N_yelp, mu_yelp))
    bayes_ratings_fsq.append(bayes_sum(row['fsq_rating_dist'], N_fsq, mu_fsq))

df_rests_selected['bayes_yelp_rating'] = bayes_ratings_yelp
df_rests_selected['bayes_fsq_rating'] = bayes_ratings_fsq
df_rests_selected.head()
# Out:
#                   yelp_id                     yelp_name  \
# 0  Iue8gacs66BJeFRG83RLEA            Halal Kitchen Cafe
# 2  -YE-UnethM8jbYFWl9ktRQ             Flavors From Afar
# 3  Mj2BC82wH_oy1YC9PanJXw      Mama D's African Cuisine
# 4  Tr4E7gyf2UUNkk3piQFdGg  Jaliz Cuisine of East Africa
# 5  u8U8Zc1Se_gY30zNeOTSqg      Moun Of Tunis Restaurant
#
#                     yelp_categories     neighborhood   latitude   longitude  \
# 0   [Halal, Middle Eastern, Afghan]     [Northridge]  34.228354 -118.528353
# 2  [Middle Eastern, Halal, African]   [Mid-Wilshire]  34.056837 -118.364192
# 3                         [African]  [Boyle Heights]  34.026788 -118.219327
# 4                         [African]       [Van Nuys]   34.19105 -118.454684
# 5        [Moroccan, African, Halal]      [Hollywood]  34.098451 -118.352524
#
#                                      display_address   display_phone is_chain  \
# 0  [18112 Parthenia St, Ste B, Northridge, CA 91325]  (818) 886-6106        0
# 2            [1046 S Fairfax, Los Angeles, CA 90019]  (323) 879-9778        0
# 3            [1240 S Soto St, Los Angeles, CA 90023]  (562) 269-9818        0
# 4           [14747 Kittridge St, Van Nuys, CA 91405]  (818) 571-2188        0
# 5    [7445 1/2 W Sunset Blvd, Los Angeles, CA 90046]  (323) 874-3333        0
#
#   yelp_is_claimed  ... fsq_total_photos fsq_total_ratings fsq_total_tips  \
# 0            True  ...              NaN               NaN            NaN
# 2            True  ...              NaN               NaN            NaN
# 3            True  ...              NaN               NaN            NaN
# 4            True  ...              NaN               NaN            NaN
# 5            True  ...               26                34             10
#
#                          website  \
# 0         http://www.halalkc.com
# 2  http://www.flavorsfromafar.co
# 3    https://www.mamadsfood.com/
# 4    http://www.jalizcuisine.com
# 5    http://www.mounoftunis.com/
#
#                                     yelp_rating_dist cluster  \
# 0  [2.9497774452882055, 4.147791424236157, 3.9281...     7.0
# 2  [4.370065654437283, 4.812044260796708, 4.10354...     1.0
# 3  [4.748355119565722, 4.25590733351322, 5, 4.691...     8.0
# 4  [4.371011025338866, 4.1840064065837215, 4.9456...     2.0
# 5  [4.286687403425167, 3.977754792037238, 4.13492...     0.0
#
#                                      fsq_rating_dist bayes_yelp_rating  \
# 0  [7.403515952622316, 7.8253898574929615, 7.6631...          3.812923
# 2  [8.018558927385394, 8.195349944035662, 7.86164...          4.263252
# 3  [7.191225952107329, 7.5795151030085, 7.4688658...          4.036243
# 4  [7.718855460334855, 7.896433987712421, 7.35014...          3.620330
# 5  [8.205236312969054, 7.9854174572136785, 8.1547...          3.842940
#
#   bayes_fsq_rating    metric
# 0         7.442284  6.753657
# 2         7.676177  7.343778
# 3         7.503887  6.917342
# 4         7.465515  6.258716
# 5         7.669500  6.973409
#
# [5 rows x 26 columns]

# %%
#create an overall metric, taking into account both yelp and fsq ratings:
import pandas as pd
metric_cols = [
    'bayes_yelp_rating',
    'bayes_fsq_rating'
]

df_metric = df_rests_selected[metric_cols]

#scale these columns
from sklearn.preprocessing import MinMaxScaler
max_scaler = MinMaxScaler()
df_metric = pd.DataFrame(max_scaler.fit_transform(df_metric),columns=df_metric.columns,index=df_metric.index)

df_metric.head()
# Out:
#    bayes_yelp_rating  bayes_fsq_rating
# 0           0.654256          0.675818
# 2           0.815541          0.717598
# 3           0.734238          0.686822
# 4           0.585278          0.679967
# 5           0.665006          0.716406

# %%
#average the scaled columns and mult by 10:
df_rests_selected['metric'] = df_metric.mean(axis=1) * 10
df_rests_selected.head()
# Out:
#                   yelp_id                     yelp_name  \
# 0  Iue8gacs66BJeFRG83RLEA            Halal Kitchen Cafe
# 2  -YE-UnethM8jbYFWl9ktRQ             Flavors From Afar
# 3  Mj2BC82wH_oy1YC9PanJXw      Mama D's African Cuisine
# 4  Tr4E7gyf2UUNkk3piQFdGg  Jaliz Cuisine of East Africa
# 5  u8U8Zc1Se_gY30zNeOTSqg      Moun Of Tunis Restaurant
#
#                     yelp_categories     neighborhood   latitude   longitude  \
# 0   [Halal, Middle Eastern, Afghan]     [Northridge]  34.228354 -118.528353
# 2  [Middle Eastern, Halal, African]   [Mid-Wilshire]  34.056837 -118.364192
# 3                         [African]  [Boyle Heights]  34.026788 -118.219327
# 4                         [African]       [Van Nuys]   34.19105 -118.454684
# 5        [Moroccan, African, Halal]      [Hollywood]  34.098451 -118.352524
#
#                                      display_address   display_phone is_chain  \
# 0  [18112 Parthenia St, Ste B, Northridge, CA 91325]  (818) 886-6106        0
# 2            [1046 S Fairfax, Los Angeles, CA 90019]  (323) 879-9778        0
# 3            [1240 S Soto St, Los Angeles, CA 90023]  (562) 269-9818        0
# 4           [14747 Kittridge St, Van Nuys, CA 91405]  (818) 571-2188        0
# 5    [7445 1/2 W Sunset Blvd, Los Angeles, CA 90046]  (323) 874-3333        0
#
#   yelp_is_claimed  ... fsq_total_photos fsq_total_ratings fsq_total_tips  \
# 0            True  ...              NaN               NaN            NaN
# 2            True  ...              NaN               NaN            NaN
# 3            True  ...              NaN               NaN            NaN
# 4            True  ...              NaN               NaN            NaN
# 5            True  ...               26                34             10
#
#                          website  \
# 0         http://www.halalkc.com
# 2  http://www.flavorsfromafar.co
# 3    https://www.mamadsfood.com/
# 4    http://www.jalizcuisine.com
# 5    http://www.mounoftunis.com/
#
#                                     yelp_rating_dist cluster  \
# 0  [2.9497774452882055, 4.147791424236157, 3.9281...     7.0
# 2  [4.370065654437283, 4.812044260796708, 4.10354...     1.0
# 3  [4.748355119565722, 4.25590733351322, 5, 4.691...     8.0
# 4  [4.371011025338866, 4.1840064065837215, 4.9456...     2.0
# 5  [4.286687403425167, 3.977754792037238, 4.13492...     0.0
#
#                                      fsq_rating_dist bayes_yelp_rating  \
# 0  [7.403515952622316, 7.8253898574929615, 7.6631...          3.812923
# 2  [8.018558927385394, 8.195349944035662, 7.86164...          4.263252
# 3  [7.191225952107329, 7.5795151030085, 7.4688658...          4.036243
# 4  [7.718855460334855, 7.896433987712421, 7.35014...          3.620330
# 5  [8.205236312969054, 7.9854174572136785, 8.1547...          3.842940
#
#   bayes_fsq_rating    metric
# 0         7.442284  6.650367
# 2         7.676177  7.665696
# 3         7.503887  7.105299
# 4         7.465515  6.326229
# 5         7.669500  6.907061
#
# [5 rows x 26 columns]

# %%
#create dictionaries with the restaurant info
from collections import defaultdict
rest_neigh_dict = defaultdict(list)
rest_cuisine_dict = defaultdict(list)
rest_price_dict = defaultdict(list)

for row in df_rests_selected.index:
    this_rest = {
        'yelp_id': df_rests_selected.loc[row,'yelp_id'],
        'name': df_rests_selected.loc[row,'yelp_name'],
        'neighborhood': df_rests_selected.loc[row,'neighborhood'],
        'categories': df_rests_selected.loc[row,'yelp_categories'],
        'price': df_rests_selected.loc[row,'yelp_price'],
        'yelp_rating': df_rests_selected.loc[row,'yelp_rating'],
        'fsq_rating': df_rests_selected.loc[row,'fsq_rating'],
        'yelp_review_count': df_rests_selected.loc[row,'yelp_review_count'],
        'fsq_total_ratings': df_rests_selected.loc[row,'fsq_total_ratings'],
        'bayes_yelp_rating': df_rests_selected.loc[row,'bayes_yelp_rating'],
        'bayes_fsq_rating': df_rests_selected.loc[row,'bayes_fsq_rating'],
        'metric': df_rests_selected.loc[row,'metric'],
        'lat': df_rests_selected.loc[row,'latitude'],
        'long': df_rests_selected.loc[row,'longitude'],
        'display_address': df_rests_selected.loc[row,'display_address'],
        'display_phone': df_rests_selected.loc[row,'display_phone'],
        'website': df_rests_selected.loc[row,'website']
    }
    for neigh in df_rests_selected.loc[row,'neighborhood']:
        rest_neigh_dict[neigh].append(this_rest)
    for cat in df_rests_selected.loc[row,'yelp_categories']:
        rest_cuisine_dict[cat].append(this_rest)
    if '$' in str(df_rests_selected.loc[row,'yelp_price']):
        price = df_rests_selected.loc[row,'yelp_price']
        rest_price_dict[price].append(this_rest)

# %%
top_rests = pd.DataFrame(rest_neigh_dict['West Hollywood'])
top_rests.sort_values(by=['metric'],axis=0,ascending=False)
#it appears that people using fsq have bias towards fast casual
#do not use fsq ratings, instead just use the bayes_yelp_rating
# Out:
#                     yelp_id                                      name  \
# 88   mfRAMQGOdQk_v1CmjXq3Eg                 Soho House West Hollywood
# 92   Su2ts0CfPazGJe6zWNb12A                          Fresh Corn Grill
# 32   5miNhLxuxaW5zLEchv6oPw                               Dialog Cafe
# 0    cal0Wpupxj9c_AV7WzDXsw                                 GRANVILLE
# 104  QLXO-aOTh06CaA8_E9wt2w                Otus Thai Kitchen & Coffee
# ..                      ...                                       ...
# 39   oVL1_eSh_gSOMKpDIkEg4Q                             Coffee Coffee
# 66   Qs_XdaqCGWU8CF5_Y_gKwA                       Sushi Ginza Onodera
# 36   UdY7cSva5qr15zy8c3t6fw  The Artist Tree Studio Dispensary Lounge
# 42   qNB9rcprlKr87SKC6RutJQ                               Mechta Deli
# 34   X9EPhqojom3ha6QLq5POCg                          Citrus On Sunset
#
#                                             categories price  yelp_rating  \
# 88   [Middle Eastern, Cocktail Bars, Venues & Event...  $$$$          4.5
# 92                          [Pizza, Sandwiches, Salad]    $$          4.5
# 32                         [Cafes, Breakfast & Brunch]    $$          4.5
# 0                      [American (New), Cocktail Bars]    $$          4.5
# 104           [Thai, Coffee & Tea, Breakfast & Brunch]    $$          4.5
# ..                                                 ...   ...          ...
# 39       [Coffee & Tea, Breakfast & Brunch, Creperies]     $          4.0
# 66                              [Sushi Bars, Japanese]  $$$$          4.5
# 36             [Cafes, Cannabis Dispensaries, Lounges]   NaN          4.0
# 42                                             [Delis]     $          4.0
# 34                  [Cafes, Breakfast & Brunch, Pizza]     $          4.0
#
#      fsq_rating  yelp_review_count  fsq_total_ratings  bayes_yelp_rating  \
# 88          9.1                408              873.0           4.173791
# 92          8.8               1100              234.0           4.369628
# 32          8.7               1953              184.0           4.391599
# 0           8.5               2171               73.0           4.433676
# 104         8.6                615               86.0           4.365808
# ..          ...                ...                ...                ...
# 39          8.0                165               36.0           3.483393
# 66          8.2                176               12.0           3.968693
# 36          NaN                 25                NaN           2.639879
# 42          NaN                 33                NaN           2.822555
# 34          5.9                147               12.0           3.192965
#
#      bayes_fsq_rating    metric        lat        long  \
# 88           8.961024  8.653073  34.089801 -118.392811
# 92           8.530342  8.619098  34.086900 -118.380350
# 32           8.379129  8.523384  34.090509 -118.382850
# 0            8.096241  8.346069  34.077130 -118.380680
# 104          8.193647  8.311534  34.093785 -118.344225
# ..                ...       ...        ...         ...
# 39           6.368078  5.100821  34.089808 -118.361236
# 66           5.365808  5.074680  34.082126 -118.376655
# 36           7.484812  4.587724  34.087960 -118.379970
# 42           7.093512  4.565357  34.090510 -118.357020
# 34           3.946329  2.417722  34.089882 -118.392856
#
#                                        display_address   display_phone  \
# 88        [9200 Sunset Blvd, West Hollywood, CA 90069]  (310) 432-9200
# 92   [8714 Santa Monica Blvd, West Hollywood, CA 90...  (310) 855-9592
# 32        [8766 Holloway Dr, West Hollywood, CA 90069]  (310) 289-1630
# 0        [8701 Beverly Blvd, West Hollywood, CA 90048]  (424) 522-5161
# 104     [1253 N La Brea Ave, West Hollywood, CA 90038]  (323) 969-8611
# ..                                                 ...             ...
# 39      [1040 N Fairfax Ave, West Hollywood, CA 90046]  (323) 952-6590
# 66   [609 North La Cienega Blvd, West Hollywood, CA...  (323) 792-7776
# 36   [8625 Santa Monica Blvd, West Hollywood, CA 90...
# 42   [7712 Santa Monica Blvd, West Hollywood, CA 90...  (323) 654-2893
# 34   [9200 Sunset Blvd, Ste 102, West Hollywood, CA...  (310) 273-6900
#
#                                                website
# 88                          http://www.sohohousewh.com
# 92                       http://www.freshcorngrill.com
# 32                          http://www.dialog-cafe.com
# 0                            http://www.granville.net/
# 104                   https://www.otusthaikitchen.com/
# ..                                                 ...
# 39                       http://www.coffeecoffeela.com
# 66                       https://onodera-group.com/en/
# 36   https://www.theartisttree.com/studio-cannabis-...
# 42                                                 NaN
# 34                       http://www.citrusonsunset.com
#
# [107 rows x 16 columns]

# %%
top_rests = pd.DataFrame(rest_neigh_dict['West Hollywood'])
top_rests.sort_values(by=['bayes_yelp_rating'],axis=0,ascending=False)
# Out:
#                     yelp_id                                      name  \
# 103  pl5_OLDDXMOdJneeTya48A                                      LOVE
# 0    cal0Wpupxj9c_AV7WzDXsw                                 GRANVILLE
# 2    1YedTUOBgR5XmJ1BMlv70Q                                 La Bohème
# 32   5miNhLxuxaW5zLEchv6oPw                               Dialog Cafe
# 55   _DiPHeKsR9Pzk-lrAiwv-Q                                 Pura Vita
# ..                      ...                                       ...
# 100  xj7b4ueNQed23k7qHRIg-A                                   Birdies
# 99   lH5_ACeOSEOKdVMWeHnZcw                     Tasty Donuts and Cafe
# 34   X9EPhqojom3ha6QLq5POCg                          Citrus On Sunset
# 42   qNB9rcprlKr87SKC6RutJQ                               Mechta Deli
# 36   UdY7cSva5qr15zy8c3t6fw  The Artist Tree Studio Dispensary Lounge
#
#          neighborhood                                     categories price  \
# 103  [West Hollywood]                      [Vegan, Vegetarian, Thai]    $$
# 0    [West Hollywood]                [American (New), Cocktail Bars]    $$
# 2    [West Hollywood]  [Bars, American (New), Venues & Event Spaces]   $$$
# 32   [West Hollywood]                    [Cafes, Breakfast & Brunch]    $$
# 55   [West Hollywood]                    [Italian, Vegan, Wine Bars]    $$
# ..                ...                                            ...   ...
# 100  [West Hollywood]       [Donuts, Breakfast & Brunch, Sandwiches]   NaN
# 99   [West Hollywood]             [Donuts, Coffee & Tea, Sandwiches]     $
# 34   [West Hollywood]             [Cafes, Breakfast & Brunch, Pizza]     $
# 42   [West Hollywood]                                        [Delis]     $
# 36   [West Hollywood]        [Cafes, Cannabis Dispensaries, Lounges]   NaN
#
#      yelp_rating  fsq_rating  yelp_review_count  fsq_total_ratings  \
# 103          5.0         NaN                214                NaN
# 0            4.5         8.5               2171               73.0
# 2            4.5         8.0               2249               89.0
# 32           4.5         8.7               1953              184.0
# 55           4.5         8.7                715               15.0
# ..           ...         ...                ...                ...
# 100          4.0         NaN                 88                NaN
# 99           4.0         NaN                171                NaN
# 34           4.0         5.9                147               12.0
# 42           4.0         NaN                 33                NaN
# 36           4.0         NaN                 25                NaN
#
#      bayes_yelp_rating  bayes_fsq_rating    metric        lat        long  \
# 103           4.459488          7.763852  8.095414  34.091105 -118.367844
# 0             4.433676          8.096241  8.346069  34.077130 -118.380680
# 2             4.432827          7.772212  8.055138  34.090363 -118.373489
# 32            4.391599          8.379129  8.523384  34.090509 -118.382850
# 55            4.375980          7.627332  7.823938  34.090440 -118.369670
# ..                 ...               ...       ...        ...         ...
# 100           3.320805          7.497558  5.818477  34.090540 -118.361740
# 99            3.306074          6.943392  5.297136  34.091073 -118.367701
# 34            3.192965          3.946329  2.417722  34.089882 -118.392856
# 42            2.822555          7.093512  4.565357  34.090510 -118.357020
# 36            2.639879          7.484812  4.587724  34.087960 -118.379970
#
#                                        display_address   display_phone  \
# 103  [8205 Santa Monica Blvd, Unit  5, 6, West Holl...  (323) 688-2065
# 0        [8701 Beverly Blvd, West Hollywood, CA 90048]  (424) 522-5161
# 2    [8400 Santa Monica Blvd, West Hollywood, CA 90...  (323) 848-2360
# 32        [8766 Holloway Dr, West Hollywood, CA 90069]  (310) 289-1630
# 55   [8274 Santa Monica Blvd, West Hollywood, CA 90...  (323) 688-2303
# ..                                                 ...             ...
# 100  [7900 Santa Monica Blvd, West Hollywood, CA 90...  (323) 848-7161
# 99   [8205 Santa Monica Blvd, Ste 8, West Hollywood...  (323) 650-1325
# 34   [9200 Sunset Blvd, Ste 102, West Hollywood, CA...  (310) 273-6900
# 42   [7712 Santa Monica Blvd, West Hollywood, CA 90...  (323) 654-2893
# 36   [8625 Santa Monica Blvd, West Hollywood, CA 90...
#
#                                                website
# 103                         http://www.loveinweho.com/
# 0                            http://www.granville.net/
# 2              http://www.globaldiningca.com/laboheme/
# 32                          http://www.dialog-cafe.com
# 55                  http://www.puravitalosangeles.com/
# ..                                                 ...
# 100                                                NaN
# 99   https://www.groupon.com/biz/west-hollywood-ca/...
# 34                       http://www.citrusonsunset.com
# 42                                                 NaN
# 36   https://www.theartisttree.com/studio-cannabis-...
#
# [107 rows x 17 columns]

# %%
#save the rest dicts:
with open(fpath + 'rest_neigh_dict.pkl','wb') as f:
    pickle.dump(rest_neigh_dict,f)

with open(fpath + 'rest_cuisine_dict.pkl','wb') as f:
    pickle.dump(rest_cuisine_dict,f)

with open(fpath + 'rest_price_dict.pkl','wb') as f:
    pickle.dump(rest_price_dict,f)

# %%
#create a dictionary with all cuisines by neighborhood
neigh_cuisines_dict = defaultdict(list)

cuisines = ['Acai Bowls',
            'Afghan',
            'African',
            'American (New)',
            'American (Traditional)',
            'Arabic',
            'Argentine',
            'Armenian',
            'Asian Fusion',
            'Australian',
            'Bagels',
            'Bakeries',
            'Bangladeshi',
            'Barbeque',
            'Bars',
            'Basque',
            'Beer Gardens',
            'Belgian',
            'Brasseries',
            'Brazilian',
            'Breakfast & Brunch',
            'Breweries',
            'Brewpubs',
            'British',
            'Bubble Tea',
            'Buffets',
            'Burgers',
            'Burmese',
            'Cafes',
            'Cajun/Creole',
            'Cambodian',
            'Cantonese',
            'Caribbean',
            'Cheesesteaks',
            'Chicken Shop',
            'Chicken Wings',
            'Chinese',
            'Cocktail Bars',
            'Coffee & Tea',
            'Coffee Roasteries',
            'Colombian',
            'Comfort Food',
            'Conveyor Belt Sushi',
            'Creperies',
            'Cuban',
            'Cupcakes',
            'Delis',
            'Desserts',
            'Dim Sum',
            'Diners',
            'Dinner Theater',
            'Dive Bars',
            'Donuts',
            'Empanadas',
            'Ethiopian',
            'Falafel',
            'Farmers Market',
            'Fast Food',
            'Filipino',
            'Fish & Chips',
            'Fondue',
            'Food Stands',
            'Food Trucks',
            'French',
            'Gastropubs',
            'Gelato',
            'Georgian',
            'German',
            'Gluten-Free',
            'Greek',
            'Hainan',
            'Halal',
            'Hawaiian',
            'Himalayan/Nepalese',
            'Honduran',
            'Hong Kong Style Cafe',
            'Hookah Bars',
            'Hot Dogs',
            'Hot Pot',
            'Ice Cream & Frozen Yogurt',
            'Indian',
            'Indonesian',
            'Irish',
            'Irish Pub',
            'Italian',
            'Izakaya',
            'Japanese',
            'Japanese Curry',
            'Juice Bars & Smoothies',
            'Karaoke',
            'Kebab',
            'Korean',
            'Kosher',
            'Laotian',
            'Latin American',
            'Lebanese',
            'Live/Raw Food',
            'Malaysian',
            'Mediterranean',
            'Mexican',
            'Middle Eastern',
            'Modern European',
            'Mongolian',
            'Moroccan',
            'New Mexican Cuisine',
            'Nicaraguan',
            'Noodles',
            'Pakistani',
            'Pan Asian',
            'Pancakes',
            'Pasta Shops',
            'Patisserie/Cake Shop',
            'Persian/Iranian',
            'Peruvian',
            'Piano Bars',
            'Pizza',
            'Poke',
            'Polish',
            'Polynesian',
            'Pop-Up Restaurants',
            'Portuguese',
            'Poutineries',
            'Pretzels',
            'Pubs',
            'Puerto Rican',
            'Ramen',
            'Russian',
            'Salad',
            'Salvadoran',
            'Sandwiches',
            'Sardinian',
            'Scandinavian',
            'Seafood',
            'Seafood Markets',
            'Shanghainese',
            'Shaved Ice',
            'Sicilian',
            'Singaporean',
            'Smokehouse',
            'Somali',
            'Soul Food',
            'Soup',
            'South African',
            'Southern',
            'Spanish',
            'Speakeasies',
            'Sports Bars',
            'Sri Lankan',
            'Steakhouses',
            'Street Vendors',
            'Supper Clubs',
            'Sushi Bars',
            'Syrian',
            'Szechuan',
            'Tacos',
            'Taiwanese',
            'Tapas Bars',
            'Tapas/Small Plates',
            'Tea Rooms',
            'Teppanyaki',
            'Tex-Mex',
            'Thai',
            'Themed Cafes',
            'Tiki Bars',
            'Trinidadian',
            'Turkish',
            'Tuscan',
            'Ukrainian',
            'Uzbek',
            'Vegan',
            'Vegetarian',
            'Venezuelan',
            'Vietnamese',
            'Waffles',
            'Whiskey Bars',
            'Wine Bars',
            'Wine Tasting Room',
            'Wineries',
            'Wraps']
neigh_cuisines_dict['All'] = cuisines

for neigh in rest_neigh_dict:
    rests = pd.DataFrame(rest_neigh_dict[neigh])
    for ind in rests.index:
        for cat in rests.loc[ind,'categories']:
            if cat in cuisines:
                if cat not in neigh_cuisines_dict[neigh]:
                    neigh_cuisines_dict[neigh].append(cat)
    neigh_cuisines_dict[neigh] = sorted(neigh_cuisines_dict[neigh])

neigh_cuisines_dict
# Out:
# defaultdict(list,
#             {'All': ['Acai Bowls',
#               'Afghan',
#               'African',
#               'American (New)',
#               'American (Traditional)',
#               'Arabic',
#               'Argentine',
#               'Armenian',
#               'Asian Fusion',
#               'Australian',
#               'Bagels',
#               'Bakeries',
#               'Bangladeshi',
#               'Barbeque',
#               'Bars',
#               'Basque',
#               'Beer Gardens',
#               'Belgian',
#               'Brasseries',
#               'Brazilian',
#               'Breakfast & Brunch',
#               'Breweries',
#               'Brewpubs',
#               'British',
#               'Bubble Tea',
#               'Buffets',
#               'Burgers',
#               'Burmese',
#               'Cafes',
#               'Cajun/Creole',
#               'Cambodian',
#               'Cantonese',
#               'Caribbean',
#               'Cheesesteaks',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Coffee Roasteries',
#               'Colombian',
#               'Comfort Food',
#               'Conveyor Belt Sushi',
#               'Creperies',
#               'Cuban',
#               'Cupcakes',
#               'Delis',
#               'Desserts',
#               'Dim Sum',
#               'Diners',
#               'Dinner Theater',
#               'Dive Bars',
#               'Donuts',
#               'Empanadas',
#               'Ethiopian',
#               'Falafel',
#               'Farmers Market',
#               'Fast Food',
#               'Filipino',
#               'Fish & Chips',
#               'Fondue',
#               'Food Stands',
#               'Food Trucks',
#               'French',
#               'Gastropubs',
#               'Gelato',
#               'Georgian',
#               'German',
#               'Gluten-Free',
#               'Greek',
#               'Hainan',
#               'Halal',
#               'Hawaiian',
#               'Himalayan/Nepalese',
#               'Honduran',
#               'Hong Kong Style Cafe',
#               'Hookah Bars',
#               'Hot Dogs',
#               'Hot Pot',
#               'Ice Cream & Frozen Yogurt',
#               'Indian',
#               'Indonesian',
#               'Irish',
#               'Irish Pub',
#               'Italian',
#               'Izakaya',
#               'Japanese',
#               'Japanese Curry',
#               'Juice Bars & Smoothies',
#               'Karaoke',
#               'Kebab',
#               'Korean',
#               'Kosher',
#               'Laotian',
#               'Latin American',
#               'Lebanese',
#               'Live/Raw Food',
#               'Malaysian',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Modern European',
#               'Mongolian',
#               'Moroccan',
#               'New Mexican Cuisine',
#               'Nicaraguan',
#               'Noodles',
#               'Pakistani',
#               'Pan Asian',
#               'Pancakes',
#               'Pasta Shops',
#               'Patisserie/Cake Shop',
#               'Persian/Iranian',
#               'Peruvian',
#               'Piano Bars',
#               'Pizza',
#               'Poke',
#               'Polish',
#               'Polynesian',
#               'Pop-Up Restaurants',
#               'Portuguese',
#               'Poutineries',
#               'Pretzels',
#               'Pubs',
#               'Puerto Rican',
#               'Ramen',
#               'Russian',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Sardinian',
#               'Scandinavian',
#               'Seafood',
#               'Seafood Markets',
#               'Shanghainese',
#               'Shaved Ice',
#               'Sicilian',
#               'Singaporean',
#               'Smokehouse',
#               'Somali',
#               'Soul Food',
#               'Soup',
#               'South African',
#               'Southern',
#               'Spanish',
#               'Speakeasies',
#               'Sports Bars',
#               'Sri Lankan',
#               'Steakhouses',
#               'Street Vendors',
#               'Supper Clubs',
#               'Sushi Bars',
#               'Syrian',
#               'Szechuan',
#               'Tacos',
#               'Taiwanese',
#               'Tapas Bars',
#               'Tapas/Small Plates',
#               'Tea Rooms',
#               'Teppanyaki',
#               'Tex-Mex',
#               'Thai',
#               'Themed Cafes',
#               'Tiki Bars',
#               'Trinidadian',
#               'Turkish',
#               'Tuscan',
#               'Ukrainian',
#               'Uzbek',
#               'Vegan',
#               'Vegetarian',
#               'Venezuelan',
#               'Vietnamese',
#               'Waffles',
#               'Whiskey Bars',
#               'Wine Bars',
#               'Wine Tasting Room',
#               'Wineries',
#               'Wraps'],
#              'Northridge': ['Afghan',
#               'American (New)',
#               'American (Traditional)',
#               'Argentine',
#               'Armenian',
#               'Asian Fusion',
#               'Bakeries',
#               'Barbeque',
#               'Bars',
#               'Beer Gardens',
#               'Breakfast & Brunch',
#               'Bubble Tea',
#               'Buffets',
#               'Burgers',
#               'Cafes',
#               'Cajun/Creole',
#               'Caribbean',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Coffee & Tea',
#               'Comfort Food',
#               'Delis',
#               'Desserts',
#               'Dim Sum',
#               'Falafel',
#               'Fast Food',
#               'Filipino',
#               'Fish & Chips',
#               'Food Trucks',
#               'Gastropubs',
#               'Greek',
#               'Hainan',
#               'Halal',
#               'Hawaiian',
#               'Hot Pot',
#               'Indian',
#               'Italian',
#               'Izakaya',
#               'Japanese',
#               'Japanese Curry',
#               'Juice Bars & Smoothies',
#               'Korean',
#               'Latin American',
#               'Lebanese',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Noodles',
#               'Persian/Iranian',
#               'Peruvian',
#               'Pizza',
#               'Poke',
#               'Ramen',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Soup',
#               'Sports Bars',
#               'Sri Lankan',
#               'Steakhouses',
#               'Sushi Bars',
#               'Syrian',
#               'Szechuan',
#               'Tacos',
#               'Taiwanese',
#               'Tea Rooms',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Vietnamese',
#               'Wraps'],
#              'Mid-Wilshire': ['African',
#               'American (New)',
#               'American (Traditional)',
#               'Asian Fusion',
#               'Bakeries',
#               'Breakfast & Brunch',
#               'Bubble Tea',
#               'Buffets',
#               'Burgers',
#               'Cafes',
#               'Cajun/Creole',
#               'Cantonese',
#               'Caribbean',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Comfort Food',
#               'Dim Sum',
#               'Diners',
#               'Donuts',
#               'Empanadas',
#               'Ethiopian',
#               'Farmers Market',
#               'Fast Food',
#               'Fish & Chips',
#               'Food Trucks',
#               'Gastropubs',
#               'Halal',
#               'Hot Dogs',
#               'Indian',
#               'Irish Pub',
#               'Italian',
#               'Izakaya',
#               'Japanese',
#               'Korean',
#               'Kosher',
#               'Latin American',
#               'Mexican',
#               'Middle Eastern',
#               'Noodles',
#               'Pizza',
#               'Ramen',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Soul Food',
#               'Soup',
#               'Southern',
#               'Sports Bars',
#               'Street Vendors',
#               'Sushi Bars',
#               'Tacos',
#               'Vegan',
#               'Vegetarian',
#               'Vietnamese'],
#              'Boyle Heights': ['African',
#               'American (Traditional)',
#               'Asian Fusion',
#               'Bakeries',
#               'Barbeque',
#               'Bars',
#               'Breakfast & Brunch',
#               'Burgers',
#               'Cafes',
#               'Chicken Wings',
#               'Chinese',
#               'Coffee & Tea',
#               'Desserts',
#               'Fast Food',
#               'Fish & Chips',
#               'Food Stands',
#               'Food Trucks',
#               'Gluten-Free',
#               'Hot Dogs',
#               'Ice Cream & Frozen Yogurt',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Latin American',
#               'Mediterranean',
#               'Mexican',
#               'Pizza',
#               'Puerto Rican',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Sports Bars',
#               'Street Vendors',
#               'Sushi Bars',
#               'Tacos',
#               'Tapas/Small Plates',
#               'Thai',
#               'Vegan',
#               'Vietnamese',
#               'Wraps'],
#              'Van Nuys': ['Acai Bowls',
#               'African',
#               'American (New)',
#               'American (Traditional)',
#               'Argentine',
#               'Armenian',
#               'Asian Fusion',
#               'Bagels',
#               'Bakeries',
#               'Barbeque',
#               'Breakfast & Brunch',
#               'Breweries',
#               'Bubble Tea',
#               'Burgers',
#               'Cafes',
#               'Caribbean',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Coffee & Tea',
#               'Colombian',
#               'Comfort Food',
#               'Creperies',
#               'Cuban',
#               'Desserts',
#               'Diners',
#               'Donuts',
#               'Empanadas',
#               'Fast Food',
#               'Fish & Chips',
#               'Food Stands',
#               'Food Trucks',
#               'Greek',
#               'Halal',
#               'Indian',
#               'Italian',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Kebab',
#               'Korean',
#               'Latin American',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Noodles',
#               'Persian/Iranian',
#               'Peruvian',
#               'Pizza',
#               'Poke',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Soup',
#               'South African',
#               'Sports Bars',
#               'Steakhouses',
#               'Street Vendors',
#               'Sushi Bars',
#               'Syrian',
#               'Tacos',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Wraps'],
#              'Hollywood': ['Acai Bowls',
#               'African',
#               'American (New)',
#               'American (Traditional)',
#               'Armenian',
#               'Asian Fusion',
#               'Bakeries',
#               'Barbeque',
#               'Bars',
#               'Brasseries',
#               'Brazilian',
#               'Breakfast & Brunch',
#               'Brewpubs',
#               'British',
#               'Buffets',
#               'Burgers',
#               'Cafes',
#               'Cajun/Creole',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Comfort Food',
#               'Creperies',
#               'Delis',
#               'Desserts',
#               'Dim Sum',
#               'Diners',
#               'Dinner Theater',
#               'Donuts',
#               'Falafel',
#               'Fast Food',
#               'Filipino',
#               'Food Stands',
#               'Food Trucks',
#               'French',
#               'Gastropubs',
#               'Georgian',
#               'Gluten-Free',
#               'Halal',
#               'Hong Kong Style Cafe',
#               'Hookah Bars',
#               'Hot Pot',
#               'Ice Cream & Frozen Yogurt',
#               'Indian',
#               'Italian',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Korean',
#               'Latin American',
#               'Lebanese',
#               'Live/Raw Food',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Moroccan',
#               'Noodles',
#               'Peruvian',
#               'Pizza',
#               'Poke',
#               'Pop-Up Restaurants',
#               'Pubs',
#               'Ramen',
#               'Russian',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Smokehouse',
#               'Soul Food',
#               'Soup',
#               'Sports Bars',
#               'Steakhouses',
#               'Sushi Bars',
#               'Syrian',
#               'Tacos',
#               'Tea Rooms',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Vietnamese',
#               'Waffles',
#               'Wine Bars',
#               'Wraps'],
#              'Inglewood': ['Acai Bowls',
#               'African',
#               'American (Traditional)',
#               'Barbeque',
#               'Bars',
#               'Breakfast & Brunch',
#               'Burgers',
#               'Burmese',
#               'Cajun/Creole',
#               'Caribbean',
#               'Chicken Wings',
#               'Chinese',
#               'Coffee & Tea',
#               'Delis',
#               'Desserts',
#               'Diners',
#               'Donuts',
#               'Ethiopian',
#               'Halal',
#               'Ice Cream & Frozen Yogurt',
#               'Indian',
#               'Italian',
#               'Juice Bars & Smoothies',
#               'Latin American',
#               'Malaysian',
#               'Mexican',
#               'Pakistani',
#               'Pasta Shops',
#               'Pizza',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Somali',
#               'Soul Food',
#               'Soup',
#               'Southern',
#               'Sports Bars',
#               'Tacos',
#               'Vegan',
#               'Wraps'],
#              'Westlake': ['American (New)',
#               'Asian Fusion',
#               'Bakeries',
#               'Barbeque',
#               'Brazilian',
#               'Breakfast & Brunch',
#               'Burgers',
#               'Burmese',
#               'Cafes',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Cuban',
#               'Delis',
#               'Dive Bars',
#               'Fast Food',
#               'Filipino',
#               'Food Stands',
#               'Food Trucks',
#               'Gastropubs',
#               'Gluten-Free',
#               'Halal',
#               'Hawaiian',
#               'Hot Dogs',
#               'Hot Pot',
#               'Indian',
#               'Italian',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Karaoke',
#               'Korean',
#               'Latin American',
#               'Mexican',
#               'Mongolian',
#               'Noodles',
#               'Pizza',
#               'Poke',
#               'Ramen',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Soup',
#               'Southern',
#               'Sushi Bars',
#               'Szechuan',
#               'Tapas Bars',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Wine Bars'],
#              'Culver City': ['American (New)',
#               'American (Traditional)',
#               'Argentine',
#               'Asian Fusion',
#               'Bakeries',
#               'Barbeque',
#               'Bars',
#               'Brazilian',
#               'Breakfast & Brunch',
#               'Brewpubs',
#               'Bubble Tea',
#               'Buffets',
#               'Burgers',
#               'Burmese',
#               'Cafes',
#               'Caribbean',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Cupcakes',
#               'Delis',
#               'Diners',
#               'Donuts',
#               'Empanadas',
#               'Ethiopian',
#               'Fish & Chips',
#               'Food Trucks',
#               'French',
#               'Gastropubs',
#               'Gluten-Free',
#               'Greek',
#               'Halal',
#               'Indian',
#               'Italian',
#               'Izakaya',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Karaoke',
#               'Korean',
#               'Latin American',
#               'Live/Raw Food',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Noodles',
#               'Pakistani',
#               'Peruvian',
#               'Pizza',
#               'Poke',
#               'Ramen',
#               'Salad',
#               'Sandwiches',
#               'Sardinian',
#               'Scandinavian',
#               'Seafood',
#               'Seafood Markets',
#               'Soup',
#               'Steakhouses',
#               'Sushi Bars',
#               'Tacos',
#               'Tapas/Small Plates',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Wine Bars'],
#              'Pasadena': ['Acai Bowls',
#               'American (New)',
#               'American (Traditional)',
#               'Argentine',
#               'Armenian',
#               'Asian Fusion',
#               'Bakeries',
#               'Barbeque',
#               'Bars',
#               'Basque',
#               'Brazilian',
#               'Breakfast & Brunch',
#               'British',
#               'Bubble Tea',
#               'Burgers',
#               'Cafes',
#               'Cajun/Creole',
#               'Cantonese',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Comfort Food',
#               'Creperies',
#               'Delis',
#               'Desserts',
#               'Dim Sum',
#               'Diners',
#               'Dinner Theater',
#               'Donuts',
#               'Empanadas',
#               'Fast Food',
#               'Filipino',
#               'Fish & Chips',
#               'Food Stands',
#               'Food Trucks',
#               'French',
#               'Gastropubs',
#               'Gelato',
#               'Gluten-Free',
#               'Greek',
#               'Halal',
#               'Hawaiian',
#               'Himalayan/Nepalese',
#               'Hot Dogs',
#               'Hot Pot',
#               'Ice Cream & Frozen Yogurt',
#               'Indian',
#               'Indonesian',
#               'Italian',
#               'Izakaya',
#               'Japanese',
#               'Japanese Curry',
#               'Juice Bars & Smoothies',
#               'Kebab',
#               'Korean',
#               'Latin American',
#               'Lebanese',
#               'Live/Raw Food',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'New Mexican Cuisine',
#               'Noodles',
#               'Pan Asian',
#               'Pasta Shops',
#               'Persian/Iranian',
#               'Peruvian',
#               'Pizza',
#               'Poke',
#               'Pop-Up Restaurants',
#               'Pubs',
#               'Ramen',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Shaved Ice',
#               'Singaporean',
#               'Soup',
#               'Southern',
#               'Spanish',
#               'Sports Bars',
#               'Steakhouses',
#               'Sushi Bars',
#               'Tacos',
#               'Taiwanese',
#               'Tapas/Small Plates',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Venezuelan',
#               'Vietnamese',
#               'Waffles',
#               'Whiskey Bars',
#               'Wine Bars'],
#              'Sherman Oaks': ['Acai Bowls',
#               'American (New)',
#               'American (Traditional)',
#               'Armenian',
#               'Asian Fusion',
#               'Barbeque',
#               'Bars',
#               'Brazilian',
#               'Breakfast & Brunch',
#               'Bubble Tea',
#               'Burgers',
#               'Cafes',
#               'Cajun/Creole',
#               'Chicken Shop',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Delis',
#               'Desserts',
#               'Donuts',
#               'Falafel',
#               'Fast Food',
#               'Fish & Chips',
#               'Food Trucks',
#               'French',
#               'Gastropubs',
#               'Gluten-Free',
#               'Greek',
#               'Halal',
#               'Hawaiian',
#               'Indian',
#               'Italian',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Kebab',
#               'Kosher',
#               'Latin American',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Modern European',
#               'Noodles',
#               'Pizza',
#               'Poke',
#               'Portuguese',
#               'Pubs',
#               'Ramen',
#               'Russian',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Seafood Markets',
#               'Sicilian',
#               'Soul Food',
#               'Soup',
#               'Southern',
#               'Sports Bars',
#               'Steakhouses',
#               'Sushi Bars',
#               'Tacos',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Vietnamese',
#               'Waffles',
#               'Wine Bars',
#               'Wraps'],
#              'Toluca Lake': ['American (New)',
#               'American (Traditional)',
#               'Argentine',
#               'Asian Fusion',
#               'Bakeries',
#               'Bars',
#               'Breakfast & Brunch',
#               'Burgers',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Delis',
#               'Desserts',
#               'Food Trucks',
#               'Irish Pub',
#               'Italian',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Mexican',
#               'Noodles',
#               'Pizza',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Soup',
#               'Sports Bars',
#               'Steakhouses',
#               'Sushi Bars',
#               'Tacos',
#               'Thai',
#               'Vegan',
#               'Vietnamese',
#               'Whiskey Bars'],
#              'Downtown': ['American (New)',
#               'American (Traditional)',
#               'Argentine',
#               'Armenian',
#               'Asian Fusion',
#               'Bagels',
#               'Bakeries',
#               'Barbeque',
#               'Bars',
#               'Brasseries',
#               'Brazilian',
#               'Breakfast & Brunch',
#               'Breweries',
#               'Brewpubs',
#               'Bubble Tea',
#               'Burgers',
#               'Cafes',
#               'Cajun/Creole',
#               'Cantonese',
#               'Caribbean',
#               'Cheesesteaks',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Comfort Food',
#               'Creperies',
#               'Delis',
#               'Desserts',
#               'Diners',
#               'Donuts',
#               'Falafel',
#               'Fast Food',
#               'Filipino',
#               'Food Stands',
#               'Food Trucks',
#               'French',
#               'Gastropubs',
#               'German',
#               'Gluten-Free',
#               'Halal',
#               'Hawaiian',
#               'Hot Dogs',
#               'Hot Pot',
#               'Ice Cream & Frozen Yogurt',
#               'Indian',
#               'Irish',
#               'Italian',
#               'Izakaya',
#               'Japanese',
#               'Japanese Curry',
#               'Juice Bars & Smoothies',
#               'Kebab',
#               'Korean',
#               'Kosher',
#               'Latin American',
#               'Live/Raw Food',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Modern European',
#               'New Mexican Cuisine',
#               'Noodles',
#               'Pakistani',
#               'Pasta Shops',
#               'Persian/Iranian',
#               'Peruvian',
#               'Pizza',
#               'Pop-Up Restaurants',
#               'Portuguese',
#               'Pubs',
#               'Puerto Rican',
#               'Ramen',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Seafood Markets',
#               'Shaved Ice',
#               'Soul Food',
#               'Soup',
#               'Southern',
#               'Spanish',
#               'Sports Bars',
#               'Steakhouses',
#               'Street Vendors',
#               'Sushi Bars',
#               'Tacos',
#               'Taiwanese',
#               'Tapas/Small Plates',
#               'Teppanyaki',
#               'Tex-Mex',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Vietnamese',
#               'Wine Bars',
#               'Wraps'],
#              'Arlington Heights': ['American (New)',
#               'Bakeries',
#               'Barbeque',
#               'Burgers',
#               'Cafes',
#               'Caribbean',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Comfort Food',
#               'Delis',
#               'Food Stands',
#               'Italian',
#               'Korean',
#               'Latin American',
#               'Mexican',
#               'Noodles',
#               'Pizza',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Soup',
#               'Southern'],
#              'Beverly Hills': ['American (New)',
#               'American (Traditional)',
#               'Asian Fusion',
#               'Bakeries',
#               'Barbeque',
#               'Bars',
#               'Brazilian',
#               'Breakfast & Brunch',
#               'Burgers',
#               'Cafes',
#               'Cantonese',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Creperies',
#               'Delis',
#               'Desserts',
#               'Dim Sum',
#               'Diners',
#               'French',
#               'Gelato',
#               'Gluten-Free',
#               'Greek',
#               'Halal',
#               'Hot Pot',
#               'Ice Cream & Frozen Yogurt',
#               'Indian',
#               'Italian',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Korean',
#               'Kosher',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Modern European',
#               'Moroccan',
#               'Noodles',
#               'Pasta Shops',
#               'Persian/Iranian',
#               'Pizza',
#               'Ramen',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Steakhouses',
#               'Sushi Bars',
#               'Tacos',
#               'Tapas/Small Plates',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Wine Bars',
#               'Wraps'],
#              'Glendale': ['American (New)',
#               'American (Traditional)',
#               'Argentine',
#               'Armenian',
#               'Asian Fusion',
#               'Bakeries',
#               'Barbeque',
#               'Bars',
#               'Brazilian',
#               'Breakfast & Brunch',
#               'Bubble Tea',
#               'Burgers',
#               'Cafes',
#               'Cajun/Creole',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Comfort Food',
#               'Conveyor Belt Sushi',
#               'Cuban',
#               'Delis',
#               'Desserts',
#               'Dim Sum',
#               'Diners',
#               'Donuts',
#               'Empanadas',
#               'Fast Food',
#               'Filipino',
#               'Fish & Chips',
#               'Food Stands',
#               'French',
#               'Gastropubs',
#               'Georgian',
#               'German',
#               'Gluten-Free',
#               'Greek',
#               'Halal',
#               'Hawaiian',
#               'Hookah Bars',
#               'Hot Dogs',
#               'Hot Pot',
#               'Ice Cream & Frozen Yogurt',
#               'Indian',
#               'Italian',
#               'Izakaya',
#               'Japanese',
#               'Japanese Curry',
#               'Juice Bars & Smoothies',
#               'Kebab',
#               'Korean',
#               'Latin American',
#               'Lebanese',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Modern European',
#               'Noodles',
#               'Pasta Shops',
#               'Persian/Iranian',
#               'Peruvian',
#               'Pizza',
#               'Poke',
#               'Pubs',
#               'Ramen',
#               'Russian',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Seafood Markets',
#               'Shanghainese',
#               'Soup',
#               'Spanish',
#               'Sports Bars',
#               'Steakhouses',
#               'Sushi Bars',
#               'Syrian',
#               'Tacos',
#               'Taiwanese',
#               'Tapas Bars',
#               'Teppanyaki',
#               'Thai',
#               'Tiki Bars',
#               'Vegan',
#               'Vegetarian',
#               'Venezuelan',
#               'Vietnamese',
#               'Waffles',
#               'Wine Bars'],
#              'East Hollywood': ['American (New)',
#               'American (Traditional)',
#               'Argentine',
#               'Armenian',
#               'Asian Fusion',
#               'Bakeries',
#               'Barbeque',
#               'Breakfast & Brunch',
#               'Buffets',
#               'Burgers',
#               'Cafes',
#               'Cajun/Creole',
#               'Cheesesteaks',
#               'Chicken Shop',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Comfort Food',
#               'Delis',
#               'Desserts',
#               'Empanadas',
#               'Falafel',
#               'Fast Food',
#               'Filipino',
#               'Fish & Chips',
#               'Gluten-Free',
#               'Halal',
#               'Hookah Bars',
#               'Hot Pot',
#               'Indian',
#               'Italian',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Kebab',
#               'Korean',
#               'Latin American',
#               'Lebanese',
#               'Live/Raw Food',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Mongolian',
#               'Noodles',
#               'Pizza',
#               'Ramen',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Soup',
#               'Sushi Bars',
#               'Tacos',
#               'Tex-Mex',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Vietnamese',
#               'Wine Bars',
#               'Wraps'],
#              'Larchmont': ['American (New)',
#               'Argentine',
#               'Barbeque',
#               'Breakfast & Brunch',
#               'Cafes',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Empanadas',
#               'Fast Food',
#               'Food Stands',
#               'Gluten-Free',
#               'Italian',
#               'Korean',
#               'Mexican',
#               'Mongolian',
#               'Noodles',
#               'Peruvian',
#               'Pizza',
#               'Ramen',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Soul Food',
#               'Sushi Bars',
#               'Vegan',
#               'Vegetarian',
#               'Wine Bars'],
#              'Studio City': ['Acai Bowls',
#               'American (New)',
#               'American (Traditional)',
#               'Argentine',
#               'Armenian',
#               'Asian Fusion',
#               'Bagels',
#               'Bakeries',
#               'Barbeque',
#               'Bars',
#               'Brazilian',
#               'Breakfast & Brunch',
#               'British',
#               'Burgers',
#               'Cafes',
#               'Caribbean',
#               'Cheesesteaks',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Creperies',
#               'Desserts',
#               'Donuts',
#               'Falafel',
#               'Fast Food',
#               'Food Trucks',
#               'French',
#               'Gastropubs',
#               'Gelato',
#               'Gluten-Free',
#               'Halal',
#               'Hawaiian',
#               'Hookah Bars',
#               'Hot Dogs',
#               'Ice Cream & Frozen Yogurt',
#               'Indian',
#               'Italian',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Kebab',
#               'Korean',
#               'Lebanese',
#               'Live/Raw Food',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Modern European',
#               'Noodles',
#               'Pizza',
#               'Poke',
#               'Pubs',
#               'Ramen',
#               'Russian',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Seafood Markets',
#               'Soup',
#               'Southern',
#               'Sports Bars',
#               'Steakhouses',
#               'Supper Clubs',
#               'Sushi Bars',
#               'Tacos',
#               'Tapas/Small Plates',
#               'Tea Rooms',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Vietnamese',
#               'Waffles',
#               'Wine Bars'],
#              'Shadow Hills': ['American (New)',
#               'Bars',
#               'Breakfast & Brunch',
#               'Burgers',
#               'Cafes',
#               'Coffee & Tea',
#               'Italian',
#               'Mexican',
#               'Tacos'],
#              'Fairfax': ['Acai Bowls',
#               'American (New)',
#               'American (Traditional)',
#               'Argentine',
#               'Asian Fusion',
#               'Bakeries',
#               'Barbeque',
#               'Bars',
#               'Beer Gardens',
#               'Brazilian',
#               'Breakfast & Brunch',
#               'British',
#               'Burgers',
#               'Cafes',
#               'Chicken Wings',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Creperies',
#               'Delis',
#               'Desserts',
#               'Fast Food',
#               'French',
#               'Gastropubs',
#               'German',
#               'Halal',
#               'Hookah Bars',
#               'Indian',
#               'Italian',
#               'Izakaya',
#               'Japanese',
#               'Japanese Curry',
#               'Juice Bars & Smoothies',
#               'Kosher',
#               'Lebanese',
#               'Mediterranean',
#               'Mexican',
#               'Modern European',
#               'Noodles',
#               'Pasta Shops',
#               'Patisserie/Cake Shop',
#               'Pizza',
#               'Pubs',
#               'Ramen',
#               'Russian',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Shaved Ice',
#               'Southern',
#               'Speakeasies',
#               'Sports Bars',
#               'Steakhouses',
#               'Sushi Bars',
#               'Tacos',
#               'Tapas/Small Plates',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Vietnamese',
#               'Wine Bars',
#               'Wraps'],
#              'South Pasadena': ['American (New)',
#               'American (Traditional)',
#               'Asian Fusion',
#               'Bakeries',
#               'Barbeque',
#               'Bars',
#               'Breakfast & Brunch',
#               'Bubble Tea',
#               'Burgers',
#               'Cafes',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Diners',
#               'French',
#               'Hawaiian',
#               'Indian',
#               'Italian',
#               'Japanese',
#               'Kebab',
#               'Korean',
#               'Latin American',
#               'Mediterranean',
#               'Mexican',
#               'Pizza',
#               'Poke',
#               'Ramen',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Sports Bars',
#               'Sushi Bars',
#               'Taiwanese',
#               'Vegan',
#               'Vegetarian',
#               'Wine Bars'],
#              'Santa Monica': ['Acai Bowls',
#               'American (New)',
#               'American (Traditional)',
#               'Asian Fusion',
#               'Bagels',
#               'Bakeries',
#               'Bars',
#               'Beer Gardens',
#               'Breakfast & Brunch',
#               'Bubble Tea',
#               'Burgers',
#               'Cafes',
#               'Caribbean',
#               'Cheesesteaks',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Creperies',
#               'Delis',
#               'Desserts',
#               'Diners',
#               'Donuts',
#               'Empanadas',
#               'Falafel',
#               'Fish & Chips',
#               'Food Stands',
#               'Food Trucks',
#               'French',
#               'Gastropubs',
#               'Gluten-Free',
#               'Halal',
#               'Himalayan/Nepalese',
#               'Hot Dogs',
#               'Ice Cream & Frozen Yogurt',
#               'Indian',
#               'Indonesian',
#               'Irish Pub',
#               'Italian',
#               'Izakaya',
#               'Japanese',
#               'Japanese Curry',
#               'Juice Bars & Smoothies',
#               'Korean',
#               'Latin American',
#               'Live/Raw Food',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'New Mexican Cuisine',
#               'Noodles',
#               'Pancakes',
#               'Pasta Shops',
#               'Pizza',
#               'Poke',
#               'Polish',
#               'Pubs',
#               'Ramen',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Seafood Markets',
#               'Singaporean',
#               'Soup',
#               'Spanish',
#               'Sports Bars',
#               'Steakhouses',
#               'Sushi Bars',
#               'Tacos',
#               'Taiwanese',
#               'Tapas Bars',
#               'Tapas/Small Plates',
#               'Thai',
#               'Tiki Bars',
#               'Vegan',
#               'Vegetarian',
#               'Vietnamese',
#               'Waffles',
#               'Whiskey Bars',
#               'Wine Bars',
#               'Wraps'],
#              'Silver Lake': ['Acai Bowls',
#               'American (New)',
#               'American (Traditional)',
#               'Asian Fusion',
#               'Bakeries',
#               'Barbeque',
#               'Bars',
#               'Brazilian',
#               'Breakfast & Brunch',
#               'Bubble Tea',
#               'Burgers',
#               'Cafes',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Coffee Roasteries',
#               'Cuban',
#               'Desserts',
#               'Dinner Theater',
#               'Donuts',
#               'Filipino',
#               'Food Trucks',
#               'Gastropubs',
#               'German',
#               'Gluten-Free',
#               'Greek',
#               'Ice Cream & Frozen Yogurt',
#               'Indian',
#               'Italian',
#               'Izakaya',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Kebab',
#               'Latin American',
#               'Lebanese',
#               'Mediterranean',
#               'Mexican',
#               'Noodles',
#               'Peruvian',
#               'Pizza',
#               'Pubs',
#               'Ramen',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Soul Food',
#               'Spanish',
#               'Sports Bars',
#               'Sushi Bars',
#               'Tacos',
#               'Taiwanese',
#               'Tapas/Small Plates',
#               'Thai',
#               'Tuscan',
#               'Vegan',
#               'Vegetarian',
#               'Wine Bars'],
#              'Koreatown': ['Acai Bowls',
#               'American (New)',
#               'American (Traditional)',
#               'Argentine',
#               'Asian Fusion',
#               'Bagels',
#               'Bakeries',
#               'Bangladeshi',
#               'Barbeque',
#               'Bars',
#               'Brazilian',
#               'Breakfast & Brunch',
#               'Bubble Tea',
#               'Buffets',
#               'Burgers',
#               'Cafes',
#               'Cajun/Creole',
#               'Cheesesteaks',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Colombian',
#               'Comfort Food',
#               'Creperies',
#               'Delis',
#               'Desserts',
#               'Empanadas',
#               'Falafel',
#               'Fast Food',
#               'Filipino',
#               'Fish & Chips',
#               'Food Stands',
#               'Food Trucks',
#               'French',
#               'Gastropubs',
#               'Greek',
#               'Halal',
#               'Hawaiian',
#               'Hot Pot',
#               'Ice Cream & Frozen Yogurt',
#               'Indian',
#               'Italian',
#               'Izakaya',
#               'Japanese',
#               'Japanese Curry',
#               'Juice Bars & Smoothies',
#               'Karaoke',
#               'Kebab',
#               'Korean',
#               'Latin American',
#               'Lebanese',
#               'Live/Raw Food',
#               'Mediterranean',
#               'Mexican',
#               'Noodles',
#               'Pakistani',
#               'Persian/Iranian',
#               'Peruvian',
#               'Pizza',
#               'Pop-Up Restaurants',
#               'Pubs',
#               'Ramen',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Shaved Ice',
#               'Smokehouse',
#               'Soup',
#               'Spanish',
#               'Sports Bars',
#               'Steakhouses',
#               'Sushi Bars',
#               'Tacos',
#               'Taiwanese',
#               'Tapas Bars',
#               'Tapas/Small Plates',
#               'Tea Rooms',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Vietnamese',
#               'Wine Bars',
#               'Wraps'],
#              'Playa del Rey': ['American (New)',
#               'Breakfast & Brunch',
#               'Fish & Chips',
#               'French',
#               'Ice Cream & Frozen Yogurt',
#               'Indian',
#               'Italian',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Lebanese',
#               'Mediterranean',
#               'Mexican',
#               'Pizza',
#               'Seafood',
#               'Sports Bars',
#               'Sushi Bars',
#               'Whiskey Bars',
#               'Wine Bars'],
#              'El Segundo': ['American (New)',
#               'American (Traditional)',
#               'Asian Fusion',
#               'Barbeque',
#               'Bars',
#               'Brazilian',
#               'Breakfast & Brunch',
#               'Breweries',
#               'Brewpubs',
#               'Bubble Tea',
#               'Burgers',
#               'Cafes',
#               'Cheesesteaks',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Dim Sum',
#               'Diners',
#               'Fish & Chips',
#               'French',
#               'Gluten-Free',
#               'Greek',
#               'Halal',
#               'Hawaiian',
#               'Ice Cream & Frozen Yogurt',
#               'Italian',
#               'Izakaya',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Latin American',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Noodles',
#               'Pizza',
#               'Poke',
#               'Pubs',
#               'Ramen',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Soup',
#               'Sports Bars',
#               'Steakhouses',
#               'Sushi Bars',
#               'Tacos',
#               'Tapas/Small Plates',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Vietnamese'],
#              'Burbank': ['Acai Bowls',
#               'American (New)',
#               'American (Traditional)',
#               'Argentine',
#               'Armenian',
#               'Asian Fusion',
#               'Bagels',
#               'Bakeries',
#               'Barbeque',
#               'Bars',
#               'Breakfast & Brunch',
#               'Bubble Tea',
#               'Burgers',
#               'Cafes',
#               'Cajun/Creole',
#               'Caribbean',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Comfort Food',
#               'Creperies',
#               'Cuban',
#               'Delis',
#               'Desserts',
#               'Dim Sum',
#               'Diners',
#               'Dinner Theater',
#               'Empanadas',
#               'Fast Food',
#               'Fish & Chips',
#               'Food Trucks',
#               'Gastropubs',
#               'Greek',
#               'Hawaiian',
#               'Hookah Bars',
#               'Hot Dogs',
#               'Indian',
#               'Italian',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Kebab',
#               'Latin American',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'New Mexican Cuisine',
#               'Noodles',
#               'Patisserie/Cake Shop',
#               'Persian/Iranian',
#               'Peruvian',
#               'Pizza',
#               'Poke',
# ...
#               'Bars',
#               'Breakfast & Brunch',
#               'Bubble Tea',
#               'Buffets',
#               'Cafes',
#               'Cantonese',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Delis',
#               'Dim Sum',
#               'Donuts',
#               'Food Trucks',
#               'Italian',
#               'Japanese',
#               'Karaoke',
#               'Korean',
#               'Mexican',
#               'Noodles',
#               'Pizza',
#               'Ramen',
#               'Sandwiches',
#               'Seafood',
#               'Soup',
#               'Sushi Bars',
#               'Tacos',
#               'Taiwanese',
#               'Tapas/Small Plates',
#               'Thai',
#               'Vegan',
#               'Vietnamese'],
#              'Lake View Terrace': ['American (Traditional)',
#               'Breakfast & Brunch',
#               'Ethiopian',
#               'Food Trucks',
#               'Mexican'],
#              'Pico Rivera': ['American (Traditional)',
#               'Bakeries',
#               'Barbeque',
#               'Breakfast & Brunch',
#               'Burgers',
#               'Cajun/Creole',
#               'Chicken Shop',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Colombian',
#               'Delis',
#               'Desserts',
#               'Diners',
#               'Donuts',
#               'Empanadas',
#               'Fast Food',
#               'Ice Cream & Frozen Yogurt',
#               'Indian',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Latin American',
#               'Mexican',
#               'Noodles',
#               'Persian/Iranian',
#               'Peruvian',
#               'Pizza',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Soup',
#               'Sports Bars',
#               'Steakhouses',
#               'Tacos',
#               'Vegan'],
#              'Sunland': ['American (Traditional)',
#               'Bakeries',
#               'Barbeque',
#               'Breakfast & Brunch',
#               'Burgers',
#               'Chicken Wings',
#               'Chinese',
#               'Coffee & Tea',
#               'Comfort Food',
#               'Delis',
#               'Diners',
#               'Fast Food',
#               'Italian',
#               'Mediterranean',
#               'Mexican',
#               'Noodles',
#               'Pizza',
#               'Sandwiches',
#               'Seafood',
#               'Thai'],
#              'Rolling Hills Estates': ['American (Traditional)',
#               'Barbeque',
#               'Breakfast & Brunch',
#               'Burgers',
#               'Cafes',
#               'Creperies',
#               'Fish & Chips',
#               'French',
#               'Greek',
#               'Hawaiian',
#               'Ice Cream & Frozen Yogurt',
#               'Italian',
#               'Korean',
#               'Latin American',
#               'Mediterranean',
#               'Middle Eastern',
#               'Peruvian',
#               'Sandwiches',
#               'Seafood',
#               'Shaved Ice',
#               'Tacos',
#               'Vietnamese'],
#              'Sylmar': ['American (Traditional)',
#               'Barbeque',
#               'Bars',
#               'Breakfast & Brunch',
#               'Burgers',
#               'Cajun/Creole',
#               'Chicken Wings',
#               'Coffee & Tea',
#               'Delis',
#               'Fast Food',
#               'Food Stands',
#               'Food Trucks',
#               'Italian',
#               'Juice Bars & Smoothies',
#               'Mexican',
#               'Peruvian',
#               'Pizza',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Sports Bars',
#               'Tacos'],
#              'Charter Oak': ['Armenian',
#               'Bakeries',
#               'Food Trucks',
#               'Greek',
#               'Halal',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Salad',
#               'Seafood',
#               'Tacos',
#               'Thai'],
#              'Azusa': ['Acai Bowls',
#               'Asian Fusion',
#               'Barbeque',
#               'Breakfast & Brunch',
#               'Breweries',
#               'Bubble Tea',
#               'Burgers',
#               'Cafes',
#               'Coffee & Tea',
#               'Donuts',
#               'Fast Food',
#               'Gastropubs',
#               'Italian',
#               'Japanese',
#               'Japanese Curry',
#               'Juice Bars & Smoothies',
#               'Korean',
#               'Mediterranean',
#               'Mexican',
#               'Mongolian',
#               'Noodles',
#               'Pubs',
#               'Ramen',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Shaved Ice',
#               'Sushi Bars',
#               'Tacos',
#               'Taiwanese',
#               'Tex-Mex',
#               'Thai',
#               'Vegan',
#               'Vietnamese',
#               'Wraps'],
#              'Baldwin Park': ['Asian Fusion',
#               'Barbeque',
#               'Bars',
#               'Breakfast & Brunch',
#               'Bubble Tea',
#               'Burgers',
#               'Chinese',
#               'Coffee & Tea',
#               'Creperies',
#               'Dim Sum',
#               'Fast Food',
#               'Hawaiian',
#               'Italian',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Karaoke',
#               'Mexican',
#               'Noodles',
#               'Pizza',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Sushi Bars',
#               'Szechuan',
#               'Tacos',
#               'Thai',
#               'Vegan',
#               'Vietnamese'],
#              'Winnetka': ['Asian Fusion',
#               'Bakeries',
#               'Burgers',
#               'Chicken Wings',
#               'Empanadas',
#               'Filipino',
#               'Fish & Chips',
#               'Halal',
#               'Italian',
#               'Japanese',
#               'Korean',
#               'Latin American',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Pasta Shops',
#               'Persian/Iranian',
#               'Pizza',
#               'Ramen',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Sushi Bars',
#               'Tacos',
#               'Vegan',
#               'Vietnamese'],
#              'Diamond Bar': ['Asian Fusion',
#               'Barbeque',
#               'Bars',
#               'Breakfast & Brunch',
#               'Bubble Tea',
#               'Buffets',
#               'Cafes',
#               'Cantonese',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Delis',
#               'Dim Sum',
#               'Halal',
#               'Hot Dogs',
#               'Hot Pot',
#               'Indian',
#               'Italian',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Korean',
#               'Mexican',
#               'Noodles',
#               'Pizza',
#               'Poke',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Soup',
#               'Sushi Bars',
#               'Szechuan',
#               'Thai',
#               'Vietnamese'],
#              'Rowland Heights': ['Asian Fusion',
#               'Barbeque',
#               'Bars',
#               'Bubble Tea',
#               'Cajun/Creole',
#               'Cantonese',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Comfort Food',
#               'Creperies',
#               'Desserts',
#               'Food Trucks',
#               'Gastropubs',
#               'Hainan',
#               'Halal',
#               'Hot Pot',
#               'Indonesian',
#               'Italian',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Kebab',
#               'Korean',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Noodles',
#               'Peruvian',
#               'Pizza',
#               'Ramen',
#               'Sandwiches',
#               'Seafood',
#               'Shanghainese',
#               'Shaved Ice',
#               'Singaporean',
#               'Soup',
#               'Steakhouses',
#               'Sushi Bars',
#               'Szechuan',
#               'Tacos',
#               'Taiwanese',
#               'Tea Rooms',
#               'Thai',
#               'Vegan',
#               'Vegetarian',
#               'Vietnamese',
#               'Wraps'],
#              'Rosemead': ['Asian Fusion',
#               'Barbeque',
#               'Breakfast & Brunch',
#               'Bubble Tea',
#               'Cajun/Creole',
#               'Cantonese',
#               'Chicken Shop',
#               'Chinese',
#               'Coffee & Tea',
#               'Delis',
#               'Desserts',
#               'Dim Sum',
#               'Fast Food',
#               'Food Trucks',
#               'French',
#               'Halal',
#               'Hong Kong Style Cafe',
#               'Hot Pot',
#               'Indian',
#               'Indonesian',
#               'Italian',
#               'Korean',
#               'Mexican',
#               'Noodles',
#               'Pizza',
#               'Ramen',
#               'Salad',
#               'Sandwiches',
#               'Seafood',
#               'Singaporean',
#               'Soup',
#               'Sushi Bars',
#               'Szechuan',
#               'Tacos',
#               'Taiwanese',
#               'Thai',
#               'Vietnamese'],
#              'Harbor City': ['Asian Fusion',
#               'Barbeque',
#               'Chicken Wings',
#               'Chinese',
#               'Gluten-Free',
#               'Greek',
#               'Italian',
#               'Mediterranean',
#               'Mexican',
#               'Pasta Shops',
#               'Pizza',
#               'Salad',
#               'Tacos',
#               'Taiwanese',
#               'Thai',
#               'Vegan'],
#              'San Fernando': ['Asian Fusion',
#               'Breakfast & Brunch',
#               'Bubble Tea',
#               'Burgers',
#               'Cafes',
#               'Chinese',
#               'Cocktail Bars',
#               'Coffee & Tea',
#               'Comfort Food',
#               'Cuban',
#               'Fast Food',
#               'Fish & Chips',
#               'Gastropubs',
#               'Gluten-Free',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Mediterranean',
#               'Mexican',
#               'Persian/Iranian',
#               'Peruvian',
#               'Poke',
#               'Sandwiches',
#               'Seafood',
#               'Sushi Bars',
#               'Tacos',
#               'Wine Bars'],
#              'West Carson': ['Asian Fusion',
#               'Bakeries',
#               'Chinese',
#               'Coffee & Tea',
#               'Delis',
#               'Donuts',
#               'Food Trucks',
#               'Greek',
#               'Japanese',
#               'Mediterranean',
#               'Middle Eastern',
#               'Persian/Iranian',
#               'Sandwiches',
#               'Seafood',
#               'Soup',
#               'Southern',
#               'Sushi Bars',
#               'Tacos'],
#              'Irwindale': ['Barbeque',
#               'Chicken Shop',
#               'Chinese',
#               'Greek',
#               'Mediterranean',
#               'Mexican',
#               'Middle Eastern',
#               'Noodles',
#               'Thai',
#               'Vegetarian'],
#              'Hawaiian Gardens': ['Barbeque',
#               'Chicken Shop',
#               'Chicken Wings',
#               'Chinese',
#               'Comfort Food',
#               'Food Trucks',
#               'Japanese',
#               'Juice Bars & Smoothies',
#               'Korean',
#               'Mexican',
#               'Pizza',
#               'Seafood',
#               'Soul Food',
#               'Sushi Bars',
#               'Tacos'],
#              'South Whittier': ['Barbeque',
#               'Breakfast & Brunch',
#               'Burgers',
#               'Chicken Shop',
#               'Donuts',
#               'Fast Food',
#               'Food Trucks',
#               'Juice Bars & Smoothies',
#               'Mexican',
#               'Noodles',
#               'Pizza',
#               'Salad',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Tacos',
#               'Thai'],
#              'East Pasadena': ['Burgers',
#               'Chinese',
#               'Fast Food',
#               'Food Trucks',
#               'Italian',
#               'Japanese',
#               'Mexican',
#               'Pizza',
#               'Sports Bars',
#               'Sushi Bars',
#               'Thai'],
#              'Valinda': ['Breakfast & Brunch',
#               'Burgers',
#               'Desserts',
#               'Fast Food',
#               'Filipino',
#               'Food Trucks',
#               'Mexican',
#               'Sports Bars',
#               'Steakhouses'],
#              'Vincent': ['Burgers',
#               'Chicken Wings',
#               'Fast Food',
#               'Italian',
#               'Mexican',
#               'Pizza',
#               'Sandwiches'],
#              'Porter Ranch': ['Acai Bowls',
#               'Burgers',
#               'Cajun/Creole',
#               'Chinese',
#               'Fast Food',
#               'Filipino',
#               'Fish & Chips',
#               'Gastropubs',
#               'Greek',
#               'Japanese',
#               'Kebab',
#               'Korean',
#               'Mediterranean',
#               'Persian/Iranian',
#               'Pizza',
#               'Sandwiches',
#               'Seafood',
#               'Vegetarian'],
#              'Palos Verdes Estates': ['Breakfast & Brunch',
#               'Burgers',
#               'Coffee & Tea',
#               'Delis',
#               'Japanese',
#               'Mexican',
#               'Pizza',
#               'Sandwiches',
#               'Sushi Bars'],
#              'Avocado Heights': ['Cajun/Creole',
#               'Chicken Wings',
#               'Coffee & Tea',
#               'Donuts',
#               'Fast Food',
#               'Food Trucks',
#               'Japanese',
#               'Mexican',
#               'Salvadoran',
#               'Sandwiches',
#               'Seafood',
#               'Tacos'],
#              'East San Gabriel': ['Breakfast & Brunch',
#               'Bubble Tea',
#               'Cantonese',
#               'Coffee & Tea',
#               'Indian',
#               'Japanese',
#               'Mexican',
#               'Noodles',
#               'Salad',
#               'Sushi Bars',
#               'Taiwanese',
#               'Thai'],
#              'Unincorporated Santa Susana Mountains': ['Greek',
#               'Mediterranean',
#               'Mexican',
#               'Modern European',
#               'Sports Bars',
#               'Tex-Mex'],
#              'Citrus': ['Japanese',
#               'Mexican',
#               'Seafood',
#               'Sushi Bars',
#               'Thai'],
#              'South San Gabriel': ['Japanese', 'Mexican', 'Sushi Bars'],
#              'West Puente Valley': ['Food Trucks',
#               'Ice Cream & Frozen Yogurt',
#               'Mexican',
#               'Sandwiches'],
#              'South San Jose Hills': ['Food Trucks',
#               'Pizza',
#               'Salad',
#               'Sandwiches',
#               'Tacos'],
#              'Chatsworth Reservoir': ['Mexican'],
#              'East La Mirada': ['Mexican', 'Seafood'],
#              'Lancaster': ['Modern European', 'Pan Asian', 'Sicilian'],
#              'Palmdale': ['Cajun/Creole', 'Soul Food'],
#              'Castaic Canyons': ['Vietnamese']})

# %%
#save the neigh_cuisines_dict
with open(fpath + 'neigh_cuisines_dict.pkl','wb') as f:
    pickle.dump(neigh_cuisines_dict,f)

# %%
#create a dictionary with all prices by neighborhood
neigh_prices_dict = defaultdict(list)

prices = ['$','$$','$$$','$$$$']
neigh_prices_dict['All'] = prices

for neigh in rest_neigh_dict:
    rests = pd.DataFrame(rest_neigh_dict[neigh])
    for ind in rests.index:
        if rests.loc[ind,'price'] in prices:
            if rests.loc[ind,'price'] not in neigh_prices_dict[neigh]:
                neigh_prices_dict[neigh].append(rests.loc[ind,'price'])
    neigh_prices_dict[neigh] = sorted(neigh_prices_dict[neigh])

neigh_prices_dict
# Out:
# defaultdict(list,
#             {'All': ['$', '$$', '$$$', '$$$$'],
#              'Northridge': ['$', '$$', '$$$'],
#              'Mid-Wilshire': ['$', '$$'],
#              'Boyle Heights': ['$', '$$', '$$$'],
#              'Van Nuys': ['$', '$$'],
#              'Hollywood': ['$', '$$', '$$$', '$$$$'],
#              'Inglewood': ['$', '$$'],
#              'Westlake': ['$', '$$', '$$$', '$$$$'],
#              'Culver City': ['$', '$$', '$$$', '$$$$'],
#              'Pasadena': ['$', '$$', '$$$', '$$$$'],
#              'Sherman Oaks': ['$', '$$', '$$$', '$$$$'],
#              'Toluca Lake': ['$', '$$', '$$$'],
#              'Downtown': ['$', '$$', '$$$', '$$$$'],
#              'Arlington Heights': ['$', '$$', '$$$'],
#              'Beverly Hills': ['$', '$$', '$$$', '$$$$'],
#              'Glendale': ['$', '$$', '$$$', '$$$$'],
#              'East Hollywood': ['$', '$$', '$$$'],
#              'Larchmont': ['$', '$$', '$$$', '$$$$'],
#              'Studio City': ['$', '$$', '$$$', '$$$$'],
#              'Shadow Hills': ['$', '$$'],
#              'Fairfax': ['$', '$$', '$$$'],
#              'South Pasadena': ['$', '$$', '$$$'],
#              'Santa Monica': ['$', '$$', '$$$', '$$$$'],
#              'Silver Lake': ['$', '$$', '$$$', '$$$$'],
#              'Koreatown': ['$', '$$', '$$$', '$$$$'],
#              'Playa del Rey': ['$', '$$'],
#              'El Segundo': ['$', '$$', '$$$'],
#              'Burbank': ['$', '$$', '$$$', '$$$$'],
#              'North Hollywood': ['$', '$$', '$$$'],
#              'Valley Village': ['$', '$$', '$$$'],
#              'West Hollywood': ['$', '$$', '$$$', '$$$$'],
#              'Westchester': ['$', '$$', '$$$'],
#              'Downey': ['$', '$$', '$$$'],
#              'Manhattan Beach': ['$', '$$', '$$$'],
#              'Hollywood Hills': ['$$', '$$$', '$$$$'],
#              'Venice': ['$', '$$', '$$$'],
#              'Alhambra': ['$', '$$', '$$$'],
#              'Beverly Grove': ['$', '$$', '$$$', '$$$$'],
#              'Encino': ['$', '$$', '$$$', '$$$$'],
#              'Eagle Rock': ['$', '$$', '$$$'],
#              'Pico-Robertson': ['$', '$$', '$$$', '$$$$'],
#              'East Los Angeles': ['$', '$$'],
#              'Westwood': ['$', '$$', '$$$'],
#              'La Canada Flintridge': ['$', '$$', '$$$'],
#              'Exposition Park': ['$', '$$'],
#              'Chinatown': ['$', '$$', '$$$'],
#              'University Park': ['$', '$$'],
#              'Mar Vista': ['$', '$$'],
#              'Highland Park': ['$', '$$', '$$$'],
#              'Century City': ['$', '$$', '$$$', '$$$$'],
#              'Los Feliz': ['$', '$$', '$$$'],
#              'Valley Glen': ['$', '$$'],
#              'Del Rey': ['$', '$$', '$$$'],
#              'Echo Park': ['$', '$$', '$$$'],
#              'West Adams': ['$', '$$'],
#              'Playa Vista': ['$', '$$'],
#              'Sawtelle': ['$', '$$', '$$$', '$$$$'],
#              'Lynwood': ['$', '$$'],
#              'Brentwood': ['$', '$$', '$$$', '$$$$'],
#              'Carthay': ['$', '$$'],
#              'Hawthorne': ['$', '$$'],
#              'Del Aire': ['$', '$$'],
#              'Palms': ['$', '$$', '$$$', '$$$$'],
#              'Monterey Park': ['$', '$$'],
#              'Glassell Park': ['$', '$$', '$$$'],
#              'Windsor Square': ['$', '$$'],
#              'View Park-Windsor Hills': ['$$'],
#              'San Marino': ['$', '$$', '$$$$'],
#              'Huntington Park': ['$', '$$'],
#              'Harvard Heights': ['$', '$$', '$$$'],
#              'Lawndale': ['$', '$$'],
#              'Baldwin Hills/Crenshaw': ['$', '$$'],
#              'Leimert Park': ['$', '$$'],
#              'Altadena': ['$', '$$', '$$$'],
#              'Lincoln Heights': ['$', '$$'],
#              'Bell Gardens': ['$', '$$'],
#              'Pico-Union': ['$', '$$', '$$$'],
#              'West Los Angeles': ['$', '$$', '$$$', '$$$$'],
#              'Historic South-Central': ['$', '$$'],
#              'Rancho Park': ['$', '$$'],
#              'Vermont Square': ['$', '$$'],
#              'Marina del Rey': ['$', '$$', '$$$'],
#              'Manchester Square': ['$', '$$'],
#              'Elysian Valley': ['$', '$$'],
#              'Lake Balboa': ['$', '$$', '$$$'],
#              'Montebello': ['$', '$$'],
#              'Hyde Park': ['$', '$$'],
#              'Atwater Village': ['$', '$$', '$$$'],
#              'Sun Valley': ['$', '$$'],
#              'Cudahy': ['$', '$$'],
#              'Jefferson Park': ['$', '$$'],
#              'Gardena': ['$', '$$', '$$$'],
#              'Florence': ['$', '$$'],
#              'South Gate': ['$', '$$'],
#              'Pacific Palisades': ['$', '$$', '$$$'],
#              'Reseda': ['$', '$$'],
#              'Elysian Park': ['$', '$$', '$$$$'],
#              'Compton': ['$', '$$'],
#              'Beverlywood': ['$', '$$'],
#              'Commerce': ['$', '$$'],
#              'Maywood': ['$', '$$'],
#              'Paramount': ['$', '$$'],
#              'Bellflower': ['$', '$$'],
#              'Central-Alameda': ['$', '$$'],
#              'Bell': ['$', '$$'],
#              'Mid-City': ['$', '$$'],
#              'Hermosa Beach': ['$', '$$', '$$$'],
#              'Hancock Park': ['$$', '$$$$'],
#              'Panorama City': ['$', '$$'],
#              'Arleta': ['$', '$$'],
#              'Chesterfield Square': ['$', '$$'],
#              'Claremont': ['$', '$$', '$$$'],
#              'Whittier': ['$', '$$', '$$$'],
#              'Universal City': ['$$'],
#              'Willowbrook': ['$$'],
#              'Cheviot Hills': ['$', '$$', '$$$$'],
#              'Adams-Normandie': ['$', '$$'],
#              'Broadway-Manchester': ['$'],
#              'Vernon': ['$', '$$'],
#              'El Sereno': ['$', '$$'],
#              'Florence-Firestone': ['$', '$$'],
#              'Griffith Park': ['$'],
#              'La Crescenta-Montrose': ['$', '$$'],
#              'Athens': ['$$'],
#              'Harvard Park': ['$'],
#              'Gramercy Park': ['$$'],
#              'Vermont Knolls': [],
#              'Vermont-Slauson': ['$', '$$'],
#              'South Park': ['$', '$$'],
#              'Hollywood Hills West': ['$$', '$$$'],
#              'Beverly Crest': ['$$', '$$$', '$$$$'],
#              'North Hills': ['$', '$$'],
#              'Green Meadows': ['$', '$$'],
#              'Artesia': ['$', '$$', '$$$'],
#              'Alondra Park': ['$', '$$'],
#              'Redondo Beach': ['$', '$$', '$$$', '$$$$'],
#              'West Compton': ['$$'],
#              'Long Beach': ['$', '$$', '$$$', '$$$$'],
#              'Mission Hills': ['$', '$$'],
#              'Signal Hill': ['$', '$$'],
#              'Cypress Park': ['$'],
#              'Walnut Park': ['$', '$$'],
#              'Lennox': ['$', '$$'],
#              'East Compton': ['$'],
#              'Ladera Heights': ['$$'],
#              'Montecito Heights': [],
#              'Santa Clarita': ['$', '$$', '$$$', '$$$$'],
#              'Carson': ['$', '$$', '$$$'],
#              'Watts': ['$$'],
#              'Bel-Air': ['$$'],
#              'Westmont': [],
#              'Sepulveda Basin': ['$$'],
#              'Vermont Vista': ['$'],
#              'Harbor Gateway': ['$', '$$', '$$$'],
#              'Tarzana': ['$', '$$', '$$$'],
#              'West Hills': ['$', '$$'],
#              'San Gabriel': ['$', '$$', '$$$', '$$$$'],
#              'Torrance': ['$', '$$', '$$$'],
#              'Agoura Hills': ['$', '$$', '$$$'],
#              'Westlake Village': ['$', '$$', '$$$'],
#              'Monrovia': ['$', '$$'],
#              'Arcadia': ['$', '$$', '$$$'],
#              'Sierra Madre': ['$', '$$'],
#              'La Puente': ['$', '$$'],
#              'West Covina': ['$', '$$', '$$$'],
#              'South El Monte': ['$', '$$'],
#              'West Whittier-Los Nietos': ['$', '$$'],
#              'Industry': ['$', '$$', '$$$', '$$$$'],
#              'Covina': ['$', '$$', '$$$'],
#              'Glendora': ['$', '$$'],
#              'Walnut': ['$', '$$'],
#              'Calabasas': ['$', '$$', '$$$'],
#              'Woodland Hills': ['$', '$$', '$$$', '$$$$'],
#              'Canoga Park': ['$', '$$'],
#              'Granada Hills': ['$', '$$', '$$$'],
#              'Chatsworth': ['$', '$$', '$$$'],
#              'Cerritos': ['$', '$$', '$$$'],
#              'La Mirada': ['$', '$$', '$$$'],
#              'San Dimas': ['$', '$$'],
#              'Ramona': ['$', '$$'],
#              'Pomona': ['$', '$$', '$$$'],
#              'Pacoima': ['$', '$$'],
#              'Wilmington': ['$', '$$'],
#              'Lomita': ['$', '$$', '$$$'],
#              'La Verne': ['$', '$$'],
#              'Tujunga': ['$', '$$'],
#              'Lakewood': ['$', '$$', '$$$'],
#              'Malibu': ['$', '$$', '$$$', '$$$$'],
#              'Topanga': ['$$', '$$$'],
#              'Unincorporated Santa Monica Mountains': ['$$', '$$$'],
#              'Rancho Palos Verdes': ['$', '$$', '$$$$'],
#              'San Pedro': ['$', '$$'],
#              'Mayflower Village': ['$', '$$'],
#              'Temple City': ['$', '$$', '$$$'],
#              'El Monte': ['$', '$$'],
#              'Duarte': ['$', '$$'],
#              'Norwalk': ['$', '$$', '$$$'],
#              'Santa Fe Springs': ['$', '$$'],
#              'Hacienda Heights': ['$', '$$', '$$$$'],
#              'Lake View Terrace': ['$', '$$'],
#              'Pico Rivera': ['$', '$$', '$$$'],
#              'Sunland': ['$', '$$'],
#              'Rolling Hills Estates': ['$', '$$'],
#              'Sylmar': ['$', '$$'],
#              'Charter Oak': ['$', '$$'],
#              'Azusa': ['$', '$$'],
#              'Baldwin Park': ['$', '$$'],
#              'Winnetka': ['$', '$$'],
#              'Diamond Bar': ['$', '$$', '$$$'],
#              'Rowland Heights': ['$', '$$', '$$$', '$$$$'],
#              'Rosemead': ['$', '$$', '$$$'],
#              'Harbor City': ['$', '$$', '$$$'],
#              'San Fernando': ['$', '$$'],
#              'West Carson': ['$', '$$'],
#              'Irwindale': ['$', '$$'],
#              'Hawaiian Gardens': ['$', '$$'],
#              'South Whittier': ['$', '$$'],
#              'East Pasadena': ['$', '$$'],
#              'Valinda': ['$', '$$'],
#              'Vincent': ['$', '$$'],
#              'Porter Ranch': ['$', '$$'],
#              'Palos Verdes Estates': ['$', '$$'],
#              'Avocado Heights': ['$'],
#              'East San Gabriel': ['$', '$$'],
#              'Unincorporated Santa Susana Mountains': ['$$'],
#              'Citrus': ['$', '$$'],
#              'South San Gabriel': ['$', '$$'],
#              'West Puente Valley': ['$'],
#              'South San Jose Hills': ['$', '$$'],
#              'Chatsworth Reservoir': ['$'],
#              'East La Mirada': ['$', '$$'],
#              'Lancaster': ['$', '$$$'],
#              'Palmdale': ['$$'],
#              'Castaic Canyons': ['$$']})

# %%
#save the neigh_prices_dict
with open(fpath + 'neigh_prices_dict.pkl','wb') as f:
    pickle.dump(neigh_prices_dict,f)

# %%
#create a dictionary with all prices by cuisine
cuisine_prices_dict = defaultdict(list)

prices = ['$','$$','$$$','$$$$']
cuisine_prices_dict['All'] = prices

for cuisine in neigh_cuisines_dict['All']:
    rests = df_rests_selected
    for ind in rests.index:
        for cat in rests.loc[ind,'yelp_categories']:
            if cat in cuisine and rests.loc[ind,'yelp_price'] in prices:
                if rests.loc[ind,'yelp_price'] not in cuisine_prices_dict[cuisine]:
                    cuisine_prices_dict[cuisine].append(rests.loc[ind,'yelp_price'])
    cuisine_prices_dict[cuisine] = sorted(cuisine_prices_dict[cuisine])

cuisine_prices_dict
# Out:
# defaultdict(list,
#             {'All': ['$', '$$', '$$$', '$$$$'],
#              'Acai Bowls': ['$', '$$'],
#              'Afghan': ['$$'],
#              'African': ['$$'],
#              'American (New)': ['$', '$$', '$$$', '$$$$'],
#              'American (Traditional)': ['$', '$$', '$$$', '$$$$'],
#              'Arabic': ['$$'],
#              'Argentine': ['$', '$$', '$$$'],
#              'Armenian': ['$', '$$', '$$$'],
#              'Asian Fusion': ['$', '$$', '$$$', '$$$$'],
#              'Australian': ['$$'],
#              'Bagels': ['$', '$$'],
#              'Bakeries': ['$', '$$', '$$$'],
#              'Bangladeshi': ['$', '$$'],
#              'Barbeque': ['$', '$$', '$$$', '$$$$'],
#              'Bars': ['$$', '$$$', '$$$$'],
#              'Basque': ['$$', '$$$'],
#              'Beer Gardens': ['$', '$$'],
#              'Belgian': ['$$'],
#              'Brasseries': ['$$$', '$$$$'],
#              'Brazilian': ['$', '$$', '$$$', '$$$$'],
#              'Breakfast & Brunch': ['$', '$$', '$$$', '$$$$'],
#              'Breweries': ['$', '$$'],
#              'Brewpubs': ['$$'],
#              'British': ['$', '$$', '$$$'],
#              'Bubble Tea': ['$', '$$'],
#              'Buffets': ['$', '$$', '$$$'],
#              'Burgers': ['$', '$$', '$$$'],
#              'Burmese': ['$', '$$'],
#              'Cafes': ['$', '$$', '$$$'],
#              'Cajun/Creole': ['$', '$$', '$$$'],
#              'Cambodian': ['$', '$$'],
#              'Cantonese': ['$', '$$'],
#              'Caribbean': ['$', '$$'],
#              'Cheesesteaks': ['$', '$$'],
#              'Chicken Shop': ['$', '$$'],
#              'Chicken Wings': ['$', '$$'],
#              'Chinese': ['$', '$$', '$$$'],
#              'Cocktail Bars': ['$', '$$', '$$$', '$$$$'],
#              'Coffee & Tea': ['$', '$$', '$$$'],
#              'Coffee Roasteries': ['$', '$$'],
#              'Colombian': ['$', '$$'],
#              'Comfort Food': ['$', '$$', '$$$'],
#              'Conveyor Belt Sushi': ['$$'],
#              'Creperies': ['$', '$$'],
#              'Cuban': ['$', '$$', '$$$'],
#              'Cupcakes': ['$$'],
#              'Delis': ['$', '$$', '$$$', '$$$$'],
#              'Desserts': ['$', '$$', '$$$'],
#              'Dim Sum': ['$', '$$'],
#              'Diners': ['$', '$$', '$$$', '$$$$'],
#              'Dinner Theater': ['$', '$$', '$$$', '$$$$'],
#              'Dive Bars': ['$', '$$', '$$$', '$$$$'],
#              'Donuts': ['$', '$$'],
#              'Empanadas': ['$', '$$'],
#              'Ethiopian': ['$', '$$'],
#              'Falafel': ['$', '$$'],
#              'Farmers Market': ['$$'],
#              'Fast Food': ['$', '$$'],
#              'Filipino': ['$', '$$', '$$$'],
#              'Fish & Chips': ['$', '$$', '$$$'],
#              'Fondue': ['$$'],
#              'Food Stands': ['$', '$$'],
#              'Food Trucks': ['$', '$$'],
#              'French': ['$', '$$', '$$$', '$$$$'],
#              'Gastropubs': ['$', '$$'],
#              'Gelato': ['$', '$$'],
#              'Georgian': ['$$'],
#              'German': ['$$'],
#              'Gluten-Free': ['$', '$$', '$$$'],
#              'Greek': ['$', '$$', '$$$'],
#              'Hainan': ['$$'],
#              'Halal': ['$', '$$'],
#              'Hawaiian': ['$', '$$'],
#              'Himalayan/Nepalese': ['$$'],
#              'Honduran': ['$', '$$'],
#              'Hong Kong Style Cafe': ['$$'],
#              'Hookah Bars': ['$', '$$', '$$$', '$$$$'],
#              'Hot Dogs': ['$', '$$'],
#              'Hot Pot': ['$', '$$', '$$$', '$$$$'],
#              'Ice Cream & Frozen Yogurt': ['$', '$$'],
#              'Indian': ['$', '$$', '$$$'],
#              'Indonesian': ['$', '$$', '$$$'],
#              'Irish': ['$$'],
#              'Irish Pub': ['$$'],
#              'Italian': ['$', '$$', '$$$', '$$$$'],
#              'Izakaya': ['$$', '$$$', '$$$$'],
#              'Japanese': ['$', '$$', '$$$', '$$$$'],
#              'Japanese Curry': ['$', '$$', '$$$', '$$$$'],
#              'Juice Bars & Smoothies': ['$', '$$', '$$$', '$$$$'],
#              'Karaoke': ['$', '$$', '$$$$'],
#              'Kebab': ['$', '$$'],
#              'Korean': ['$', '$$', '$$$', '$$$$'],
#              'Kosher': ['$', '$$', '$$$'],
#              'Laotian': ['$', '$$'],
#              'Latin American': ['$', '$$', '$$$'],
#              'Lebanese': ['$', '$$', '$$$'],
#              'Live/Raw Food': ['$', '$$', '$$$'],
#              'Malaysian': ['$', '$$'],
#              'Mediterranean': ['$', '$$', '$$$'],
#              'Mexican': ['$', '$$', '$$$', '$$$$'],
#              'Middle Eastern': ['$', '$$', '$$$', '$$$$'],
#              'Modern European': ['$', '$$', '$$$', '$$$$'],
#              'Mongolian': ['$', '$$'],
#              'Moroccan': ['$$', '$$$'],
#              'New Mexican Cuisine': ['$', '$$', '$$$', '$$$$'],
#              'Nicaraguan': ['$', '$$'],
#              'Noodles': ['$', '$$', '$$$'],
#              'Pakistani': ['$', '$$'],
#              'Pan Asian': ['$', '$$', '$$$'],
#              'Pancakes': ['$$'],
#              'Pasta Shops': ['$', '$$', '$$$'],
#              'Patisserie/Cake Shop': ['$', '$$'],
#              'Persian/Iranian': ['$', '$$'],
#              'Peruvian': ['$', '$$', '$$$'],
#              'Piano Bars': ['$$', '$$$', '$$$$'],
#              'Pizza': ['$', '$$', '$$$'],
#              'Poke': ['$', '$$'],
#              'Polish': ['$$'],
#              'Polynesian': ['$$'],
#              'Pop-Up Restaurants': ['$', '$$'],
#              'Portuguese': ['$', '$$', '$$$'],
#              'Poutineries': ['$$'],
#              'Pretzels': ['$$'],
#              'Pubs': ['$$', '$$$'],
#              'Puerto Rican': ['$'],
#              'Ramen': ['$', '$$', '$$$'],
#              'Russian': ['$$', '$$$', '$$$$'],
#              'Salad': ['$', '$$', '$$$'],
#              'Salvadoran': ['$', '$$'],
#              'Sandwiches': ['$', '$$', '$$$', '$$$$'],
#              'Sardinian': ['$$'],
#              'Scandinavian': ['$$'],
#              'Seafood': ['$', '$$', '$$$', '$$$$'],
#              'Seafood Markets': ['$', '$$', '$$$', '$$$$'],
#              'Shanghainese': ['$', '$$'],
#              'Shaved Ice': ['$', '$$'],
#              'Sicilian': ['$$', '$$$'],
#              'Singaporean': ['$', '$$', '$$$'],
#              'Smokehouse': ['$$'],
#              'Somali': ['$$'],
#              'Soul Food': ['$', '$$'],
#              'Soup': ['$', '$$', '$$$'],
#              'South African': ['$$'],
#              'Southern': ['$', '$$', '$$$'],
#              'Spanish': ['$', '$$', '$$$'],
#              'Speakeasies': ['$$'],
#              'Sports Bars': ['$', '$$', '$$$', '$$$$'],
#              'Sri Lankan': ['$', '$$'],
#              'Steakhouses': ['$$', '$$$', '$$$$'],
#              'Street Vendors': ['$', '$$'],
#              'Supper Clubs': [],
#              'Sushi Bars': ['$', '$$', '$$$', '$$$$'],
#              'Syrian': ['$$'],
#              'Szechuan': ['$', '$$', '$$$'],
#              'Tacos': ['$', '$$'],
#              'Taiwanese': ['$', '$$', '$$$$'],
#              'Tapas Bars': ['$$', '$$$', '$$$$'],
#              'Tapas/Small Plates': ['$', '$$', '$$$'],
#              'Tea Rooms': ['$', '$$'],
#              'Teppanyaki': ['$$', '$$$'],
#              'Tex-Mex': ['$', '$$'],
#              'Thai': ['$', '$$'],
#              'Themed Cafes': ['$', '$$', '$$$'],
#              'Tiki Bars': ['$$', '$$$', '$$$$'],
#              'Trinidadian': ['$$'],
#              'Turkish': ['$$'],
#              'Tuscan': ['$$'],
#              'Ukrainian': ['$', '$$'],
#              'Uzbek': ['$$', '$$$'],
#              'Vegan': ['$', '$$', '$$$'],
#              'Vegetarian': ['$', '$$', '$$$'],
#              'Venezuelan': ['$$'],
#              'Vietnamese': ['$', '$$', '$$$'],
#              'Waffles': ['$', '$$'],
#              'Whiskey Bars': ['$$', '$$$', '$$$$'],
#              'Wine Bars': ['$$', '$$$', '$$$$'],
#              'Wine Tasting Room': ['$$'],
#              'Wineries': ['$$'],
#              'Wraps': ['$', '$$', '$$$']})

# %%
#save the cuisine_prices_dict
with open(fpath + 'cuisine_prices_dict.pkl','wb') as f:
    pickle.dump(cuisine_prices_dict,f)

# %%
#create a dictionary with all prices by neigh & cuisine choice
neigh_cuisine_prices_dict = defaultdict(list)

prices = ['$','$$','$$$','$$$$']
neigh_cuisine_prices_dict['All'] = prices

for neigh in rest_neigh_dict:
    rests = pd.DataFrame(rest_neigh_dict[neigh])
    for ind in rests.index:
        for cat in rests.loc[ind,'categories']:
            if cat in neigh_cuisines_dict['All'] and rests.loc[ind,'price'] in prices:
                if rests.loc[ind,'price'] not in neigh_cuisine_prices_dict[neigh + '_' + cat]:
                    neigh_cuisine_prices_dict[neigh + '_' + cat].append(rests.loc[ind,'price'])
#sort:
for key in neigh_cuisine_prices_dict:
    neigh_cuisine_prices_dict[key] = sorted(neigh_cuisine_prices_dict[key])

neigh_cuisine_prices_dict
# Out:
# defaultdict(list,
#             {'All': ['$', '$$', '$$$', '$$$$'],
#              'Northridge_Halal': ['$', '$$'],
#              'Northridge_Middle Eastern': ['$$'],
#              'Northridge_Afghan': ['$$'],
#              'Northridge_Burgers': ['$', '$$'],
#              'Northridge_American (Traditional)': ['$', '$$'],
#              'Northridge_Gastropubs': ['$$'],
#              'Northridge_Bars': ['$$'],
#              'Northridge_Sports Bars': ['$$'],
#              'Northridge_Asian Fusion': ['$', '$$', '$$$'],
#              'Northridge_Ramen': ['$$'],
#              'Northridge_Fast Food': ['$', '$$'],
#              'Northridge_Sandwiches': ['$', '$$'],
#              'Northridge_Caribbean': ['$$'],
#              'Northridge_Latin American': ['$$'],
#              'Northridge_Desserts': ['$', '$$'],
#              'Northridge_Comfort Food': ['$'],
#              'Northridge_Bakeries': ['$', '$$'],
#              'Northridge_Delis': ['$', '$$'],
#              'Northridge_Food Trucks': ['$', '$$'],
#              'Northridge_Seafood': ['$', '$$'],
#              'Northridge_Mexican': ['$', '$$'],
#              'Northridge_Sri Lankan': ['$'],
#              'Northridge_American (New)': ['$', '$$'],
#              'Northridge_Barbeque': ['$$', '$$$'],
#              'Northridge_Salad': ['$', '$$'],
#              'Northridge_Vegetarian': ['$', '$$'],
#              'Northridge_Fish & Chips': ['$$'],
#              'Northridge_Beer Gardens': ['$$'],
#              'Northridge_Mediterranean': ['$', '$$'],
#              'Northridge_Wraps': ['$', '$$'],
#              'Northridge_Breakfast & Brunch': ['$', '$$'],
#              'Northridge_Argentine': ['$$'],
#              'Northridge_Steakhouses': ['$$'],
#              'Northridge_Armenian': ['$$'],
#              'Northridge_Hainan': ['$$'],
#              'Northridge_Chicken Shop': ['$$'],
#              'Northridge_Korean': ['$$', '$$$'],
#              'Northridge_Cajun/Creole': ['$$'],
#              'Northridge_Chicken Wings': ['$$'],
#              'Northridge_Sushi Bars': ['$$', '$$$'],
#              'Northridge_Cafes': ['$', '$$'],
#              'Northridge_Juice Bars & Smoothies': ['$', '$$'],
#              'Northridge_Coffee & Tea': ['$'],
#              'Northridge_Chinese': ['$$'],
#              'Northridge_Noodles': ['$$'],
#              'Northridge_Soup': ['$$'],
#              'Northridge_Szechuan': ['$$'],
#              'Northridge_Dim Sum': ['$$'],
#              'Northridge_Filipino': ['$'],
#              'Northridge_Tacos': ['$', '$$'],
#              'Northridge_Falafel': ['$$'],
#              'Northridge_Greek': ['$$'],
#              'Northridge_Pizza': ['$', '$$'],
#              'Northridge_Hawaiian': ['$$'],
#              'Northridge_Tea Rooms': ['$$'],
#              'Northridge_Hot Pot': ['$$'],
#              'Northridge_Bubble Tea': ['$', '$$'],
#              'Northridge_Indian': ['$$'],
#              'Northridge_Italian': ['$', '$$'],
#              'Northridge_Izakaya': ['$$$'],
#              'Northridge_Japanese': ['$$'],
#              'Northridge_Thai': ['$$'],
#              'Northridge_Japanese Curry': ['$$'],
#              'Northridge_Vegan': ['$'],
#              'Northridge_Salvadoran': ['$'],
#              'Northridge_Persian/Iranian': ['$$'],
#              'Northridge_Vietnamese': ['$', '$$'],
#              'Northridge_Poke': ['$$'],
#              'Northridge_Taiwanese': ['$'],
#              'Mid-Wilshire_Middle Eastern': ['$$'],
#              'Mid-Wilshire_Halal': ['$$'],
#              'Mid-Wilshire_African': ['$$'],
#              'Mid-Wilshire_Breakfast & Brunch': ['$', '$$'],
#              'Mid-Wilshire_American (New)': ['$$'],
#              'Mid-Wilshire_Latin American': ['$$'],
#              'Mid-Wilshire_Cafes': ['$', '$$'],
#              'Mid-Wilshire_Gastropubs': ['$$'],
#              'Mid-Wilshire_American (Traditional)': ['$$'],
#              'Mid-Wilshire_Sports Bars': ['$$'],
#              'Mid-Wilshire_Irish Pub': ['$$'],
#              'Mid-Wilshire_Sushi Bars': ['$$'],
#              'Mid-Wilshire_Asian Fusion': ['$$'],
#              'Mid-Wilshire_Japanese': ['$$'],
#              'Mid-Wilshire_Dim Sum': ['$$'],
#              'Mid-Wilshire_Indian': ['$$'],
#              'Mid-Wilshire_Buffets': ['$$'],
#              'Mid-Wilshire_Hot Dogs': ['$'],
#              'Mid-Wilshire_Burgers': ['$', '$$'],
#              'Mid-Wilshire_Fast Food': ['$'],
#              'Mid-Wilshire_Tacos': ['$$'],
#              'Mid-Wilshire_Soul Food': ['$', '$$'],
#              'Mid-Wilshire_Coffee & Tea': ['$'],
#              'Mid-Wilshire_Cajun/Creole': ['$$'],
#              'Mid-Wilshire_Caribbean': ['$'],
#              'Mid-Wilshire_Noodles': ['$$'],
#              'Mid-Wilshire_Cantonese': ['$$'],
#              'Mid-Wilshire_Italian': ['$$'],
#              'Mid-Wilshire_Pizza': ['$$'],
#              'Mid-Wilshire_Comfort Food': ['$$'],
#              'Mid-Wilshire_Farmers Market': ['$$'],
#              'Mid-Wilshire_Cocktail Bars': ['$$'],
#              'Mid-Wilshire_Diners': ['$$'],
#              'Mid-Wilshire_Ethiopian': ['$$'],
#              'Mid-Wilshire_Seafood': ['$$'],
#              'Mid-Wilshire_Fish & Chips': ['$$'],
#              'Mid-Wilshire_Salad': ['$$'],
#              'Mid-Wilshire_Ramen': ['$$'],
#              'Mid-Wilshire_Izakaya': ['$$'],
#              'Mid-Wilshire_Kosher': ['$$'],
#              'Mid-Wilshire_Mexican': ['$', '$$'],
#              'Mid-Wilshire_Salvadoran': ['$'],
#              'Mid-Wilshire_Soup': ['$'],
#              'Mid-Wilshire_Food Trucks': ['$'],
#              'Mid-Wilshire_Street Vendors': ['$'],
#              'Mid-Wilshire_Vegetarian': ['$$'],
#              'Mid-Wilshire_Vietnamese': ['$$'],
#              'Mid-Wilshire_Bubble Tea': ['$$'],
#              'Mid-Wilshire_Sandwiches': ['$'],
#              'Mid-Wilshire_Bakeries': ['$'],
#              'Mid-Wilshire_Southern': ['$$'],
#              'Mid-Wilshire_Donuts': ['$'],
#              'Mid-Wilshire_Vegan': ['$'],
#              'Boyle Heights_African': ['$$'],
#              'Boyle Heights_Ice Cream & Frozen Yogurt': ['$'],
#              'Boyle Heights_Burgers': ['$'],
#              'Boyle Heights_American (Traditional)': ['$'],
#              'Boyle Heights_Mexican': ['$', '$$'],
#              'Boyle Heights_Sushi Bars': ['$$'],
#              'Boyle Heights_Japanese': ['$', '$$'],
#              'Boyle Heights_Asian Fusion': ['$', '$$'],
#              'Boyle Heights_Vietnamese': ['$'],
#              'Boyle Heights_Chinese': ['$'],
#              'Boyle Heights_Thai': ['$'],
#              'Boyle Heights_Barbeque': ['$'],
#              'Boyle Heights_Hot Dogs': ['$'],
#              'Boyle Heights_Sandwiches': ['$', '$$'],
#              'Boyle Heights_Coffee & Tea': ['$'],
#              'Boyle Heights_Cafes': ['$', '$$'],
#              'Boyle Heights_Breakfast & Brunch': ['$', '$$'],
#              'Boyle Heights_Seafood': ['$', '$$'],
#              'Boyle Heights_Fish & Chips': ['$'],
#              'Boyle Heights_Bakeries': ['$', '$$'],
#              'Boyle Heights_Vegan': ['$', '$$'],
#              'Boyle Heights_Gluten-Free': ['$', '$$$'],
#              'Boyle Heights_Latin American': ['$', '$$'],
#              'Boyle Heights_Tacos': ['$', '$$'],
#              'Boyle Heights_Salvadoran': ['$'],
#              'Boyle Heights_Mediterranean': ['$$'],
#              'Boyle Heights_Salad': ['$$'],
#              'Boyle Heights_Food Trucks': ['$', '$$'],
#              'Boyle Heights_Juice Bars & Smoothies': ['$'],
#              'Boyle Heights_Street Vendors': ['$'],
#              'Boyle Heights_Food Stands': ['$'],
#              'Boyle Heights_Desserts': ['$', '$$'],
#              'Boyle Heights_Sports Bars': ['$$'],
#              'Boyle Heights_Pizza': ['$$'],
#              'Boyle Heights_Chicken Wings': ['$$'],
#              'Boyle Heights_Wraps': ['$'],
#              'Van Nuys_African': ['$$'],
#              'Van Nuys_Sports Bars': ['$$'],
#              'Van Nuys_American (New)': ['$$'],
#              'Van Nuys_South African': ['$$'],
#              'Van Nuys_Soup': ['$', '$$'],
#              'Van Nuys_Persian/Iranian': ['$$'],
#              'Van Nuys_Mexican': ['$', '$$'],
#              'Van Nuys_Chicken Shop': ['$'],
#              'Van Nuys_American (Traditional)': ['$', '$$'],
#              'Van Nuys_Food Trucks': ['$'],
#              'Van Nuys_Breakfast & Brunch': ['$', '$$'],
#              'Van Nuys_Colombian': ['$$'],
#              'Van Nuys_Steakhouses': ['$$'],
#              'Van Nuys_Argentine': ['$$'],
#              'Van Nuys_Barbeque': ['$$'],
#              'Van Nuys_Street Vendors': ['$$'],
#              'Van Nuys_Armenian': ['$$'],
#              'Van Nuys_Korean': ['$$'],
#              'Van Nuys_Burgers': ['$', '$$'],
#              'Van Nuys_Asian Fusion': ['$$'],
#              'Van Nuys_Sushi Bars': ['$$'],
#              'Van Nuys_Comfort Food': ['$$'],
#              'Van Nuys_Thai': ['$', '$$'],
#              'Van Nuys_Chinese': ['$', '$$'],
#              'Van Nuys_Fast Food': ['$'],
#              'Van Nuys_Salad': ['$', '$$'],
#              'Van Nuys_Cafes': ['$$'],
#              'Van Nuys_Acai Bowls': ['$', '$$'],
#              'Van Nuys_Desserts': ['$$'],
#              'Van Nuys_Empanadas': ['$$'],
#              'Van Nuys_Sandwiches': ['$', '$$'],
#              'Van Nuys_Caribbean': ['$$'],
#              'Van Nuys_Cuban': ['$$'],
#              'Van Nuys_Latin American': ['$$'],
#              'Van Nuys_Bubble Tea': ['$'],
#              'Van Nuys_Creperies': ['$'],
#              'Van Nuys_Diners': ['$$'],
#              'Van Nuys_Fish & Chips': ['$$'],
#              'Van Nuys_Mediterranean': ['$', '$$'],
#              'Van Nuys_Greek': ['$$'],
#              'Van Nuys_Kebab': ['$$'],
#              'Van Nuys_Halal': ['$$'],
#              'Van Nuys_Pizza': ['$', '$$'],
#              'Van Nuys_Italian': ['$', '$$'],
#              'Van Nuys_Japanese': ['$', '$$'],
#              'Van Nuys_Poke': ['$$'],
#              'Van Nuys_Seafood': ['$$'],
#              'Van Nuys_Middle Eastern': ['$$'],
#              'Van Nuys_Peruvian': ['$$'],
#              'Van Nuys_Bakeries': ['$'],
#              'Van Nuys_Salvadoran': ['$'],
#              'Van Nuys_Syrian': ['$$'],
#              'Van Nuys_Coffee & Tea': ['$'],
#              'Van Nuys_Vegan': ['$$'],
#              'Van Nuys_Food Stands': ['$'],
#              'Van Nuys_Tacos': ['$'],
#              'Van Nuys_Chicken Wings': ['$', '$$'],
#              'Van Nuys_Noodles': ['$', '$$'],
#              'Van Nuys_Breweries': ['$$'],
#              'Van Nuys_Wraps': ['$$'],
#              'Van Nuys_Bagels': ['$'],
#              'Van Nuys_Donuts': ['$'],
#              'Van Nuys_Juice Bars & Smoothies': ['$'],
#              'Hollywood_Moroccan': ['$$'],
#              'Hollywood_African': ['$$'],
#              'Hollywood_Halal': ['$', '$$'],
#              'Hollywood_Sandwiches': ['$', '$$', '$$$$'],
#              'Hollywood_American (New)': ['$$', '$$$', '$$$$'],
#              'Hollywood_Mediterranean': ['$', '$$'],
#              'Hollywood_Seafood': ['$', '$$', '$$$$'],
#              'Hollywood_British': ['$$'],
#              'Hollywood_Pubs': ['$$'],
#              'Hollywood_Salad': ['$', '$$'],
#              'Hollywood_Steakhouses': ['$$$', '$$$$'],
#              'Hollywood_Italian': ['$$', '$$$', '$$$$'],
#              'Hollywood_Breakfast & Brunch': ['$', '$$', '$$$'],
#              'Hollywood_Wine Bars': ['$$'],
#              'Hollywood_Vegan': ['$', '$$'],
#              'Hollywood_Vegetarian': ['$$'],
#              'Hollywood_Cocktail Bars': ['$$', '$$$'],
#              'Hollywood_Acai Bowls': ['$$'],
#              'Hollywood_Bars': ['$$', '$$$', '$$$$'],
#              'Hollywood_Dinner Theater': ['$$$$'],
#              'Hollywood_American (Traditional)': ['$', '$$', '$$$'],
#              'Hollywood_Burgers': ['$', '$$'],
#              'Hollywood_Gastropubs': ['$$'],
#              'Hollywood_Sports Bars': ['$$'],
#              'Hollywood_Russian': ['$$'],
#              'Hollywood_Armenian': ['$$'],
#              'Hollywood_Korean': ['$$'],
#              'Hollywood_Barbeque': ['$$'],
#              'Hollywood_Asian Fusion': ['$$', '$$$'],
#              'Hollywood_Vietnamese': ['$$'],
#              'Hollywood_Ramen': ['$$'],
#              'Hollywood_Dim Sum': ['$$'],
#              'Hollywood_Noodles': ['$', '$$'],
#              'Hollywood_Thai': ['$', '$$'],
#              'Hollywood_Brazilian': ['$'],
#              'Hollywood_Coffee & Tea': ['$', '$$'],
#              'Hollywood_Latin American': ['$', '$$'],
#              'Hollywood_Indian': ['$', '$$'],
#              'Hollywood_Buffets': ['$', '$$'],
#              'Hollywood_Chicken Shop': ['$', '$$'],
#              'Hollywood_Fast Food': ['$', '$$'],
#              'Hollywood_Chicken Wings': ['$$'],
#              'Hollywood_Cafes': ['$', '$$'],
#              'Hollywood_Ice Cream & Frozen Yogurt': ['$', '$$'],
#              'Hollywood_Bakeries': ['$', '$$'],
#              'Hollywood_Cajun/Creole': ['$$'],
#              'Hollywood_Soup': ['$', '$$'],
#              'Hollywood_Hong Kong Style Cafe': ['$$'],
#              'Hollywood_Chinese': ['$$'],
#              'Hollywood_Hot Pot': ['$$'],
#              'Hollywood_Desserts': ['$', '$$'],
#              'Hollywood_Comfort Food': ['$'],
#              'Hollywood_Creperies': ['$'],
#              'Hollywood_Delis': ['$', '$$'],
#              'Hollywood_Japanese': ['$', '$$', '$$$', '$$$$'],
#              'Hollywood_Diners': ['$$$'],
#              'Hollywood_Sushi Bars': ['$$', '$$$', '$$$$'],
#              'Hollywood_French': ['$$$'],
#              'Hollywood_Pizza': ['$', '$$', '$$$'],
#              'Hollywood_Georgian': ['$$'],
#              'Hollywood_Gluten-Free': ['$', '$$'],
#              'Hollywood_Mexican': ['$', '$$'],
#              'Hollywood_Middle Eastern': ['$$'],
#              'Hollywood_Poke': ['$$'],
#              'Hollywood_Salvadoran': ['$$'],
#              'Hollywood_Live/Raw Food': ['$$'],
#              'Hollywood_Juice Bars & Smoothies': ['$$'],
#              'Hollywood_Wraps': ['$$'],
#              'Hollywood_Falafel': ['$$'],
#              'Hollywood_Lebanese': ['$'],
#              'Hollywood_Hookah Bars': ['$$'],
#              'Hollywood_Tacos': ['$', '$$'],
#              'Hollywood_Food Stands': ['$', '$$'],
#              'Hollywood_Food Trucks': ['$', '$$'],
#              'Hollywood_Peruvian': ['$$'],
#              'Hollywood_Donuts': ['$'],
#              'Hollywood_Tea Rooms': ['$$'],
#              'Hollywood_Soul Food': ['$$'],
#              'Hollywood_Waffles': ['$$'],
#              'Inglewood_African': ['$$'],
#              'Inglewood_Burgers': ['$', '$$'],
#              'Inglewood_Caribbean': ['$$'],
#              'Inglewood_American (Traditional)': ['$', '$$'],
#              'Inglewood_Mexican': ['$', '$$'],
#              'Inglewood_Juice Bars & Smoothies': ['$'],
#              'Inglewood_Ice Cream & Frozen Yogurt': ['$'],
#              'Inglewood_Sports Bars': ['$$'],
#              'Inglewood_Barbeque': ['$$'],
#              'Inglewood_Burmese': ['$'],
#              'Inglewood_Malaysian': ['$'],
#              'Inglewood_Halal': ['$', '$$'],
#              'Inglewood_Cajun/Creole': ['$$'],
#              'Inglewood_Breakfast & Brunch': ['$', '$$'],
#              'Inglewood_Delis': ['$$'],
#              'Inglewood_Salad': ['$$'],
#              'Inglewood_Donuts': ['$'],
#              'Inglewood_Chinese': ['$', '$$'],
#              'Inglewood_Bars': ['$$'],
#              'Inglewood_Diners': ['$$'],
#              'Inglewood_Ethiopian': ['$$'],
#              'Inglewood_Somali': ['$$'],
#              'Inglewood_Pakistani': ['$$'],
#              'Inglewood_Indian': ['$$'],
#              'Inglewood_Pasta Shops': ['$$'],
#              'Inglewood_Italian': ['$', '$$'],
#              'Inglewood_Seafood': ['$', '$$'],
#              'Inglewood_Pizza': ['$'],
#              'Inglewood_Chicken Wings': ['$', '$$'],
#              'Inglewood_Latin American': ['$', '$$'],
#              'Inglewood_Tacos': ['$', '$$'],
#              'Inglewood_Desserts': ['$'],
#              'Inglewood_Sandwiches': ['$'],
#              'Inglewood_Coffee & Tea': ['$'],
#              'Inglewood_Soul Food': ['$', '$$'],
#              'Inglewood_Southern': ['$', '$$'],
#              'Inglewood_Vegan': ['$$'],
#              'Westlake_Burgers': ['$', '$$'],
#              'Westlake_American (New)': ['$$'],
#              'Westlake_Asian Fusion': ['$', '$$'],
#              'Westlake_Latin American': ['$$'],
#              'Westlake_Vegetarian': ['$$'],
#              'Westlake_Gastropubs': ['$$'],
#              'Westlake_Korean': ['$$', '$$$', '$$$$'],
#              'Westlake_Filipino': ['$', '$$'],
#              'Westlake_Barbeque': ['$$', '$$$'],
#              'Westlake_Hot Pot': ['$$'],
#              'Westlake_Coffee & Tea': ['$'],
#              'Westlake_Brazilian': ['$'],
#              'Westlake_Breakfast & Brunch': ['$'],
#              'Westlake_Fast Food': ['$'],
#              'Westlake_Cafes': ['$'],
#              'Westlake_Sandwiches': ['$', '$$'],
#              'Westlake_Bakeries': ['$'],
#              'Westlake_Cuban': ['$'],
#              'Westlake_Chicken Shop': ['$$'],
#              'Westlake_Szechuan': ['$$'],
#              'Westlake_Chinese': ['$', '$$'],
#              'Westlake_Thai': ['$', '$$'],
#              'Westlake_Hawaiian': ['$'],
#              'Westlake_Seafood': ['$', '$$'],
#              'Westlake_Soup': ['$', '$$'],
#              'Westlake_Delis': ['$', '$$'],
#              'Westlake_Juice Bars & Smoothies': ['$'],
#              'Westlake_Karaoke': ['$$', '$$$$'],
#              'Westlake_Hot Dogs': ['$$'],
#              'Westlake_Halal': ['$', '$$'],
#              'Westlake_Indian': ['$$'],
#              'Westlake_Food Stands': ['$$'],
#              'Westlake_Italian': ['$$'],
#              'Westlake_Ramen': ['$$'],
#              'Westlake_Sushi Bars': ['$$'],
#              'Westlake_Wine Bars': ['$$'],
#              'Westlake_Tapas Bars': ['$$'],
#              'Westlake_Chicken Wings': ['$$'],
#              'Westlake_Salvadoran': ['$'],
#              'Westlake_Mexican': ['$', '$$'],
#              'Westlake_Food Trucks': ['$'],
#              'Westlake_Salad': ['$$'],
#              'Westlake_Mongolian': ['$$'],
#              'Westlake_Pizza': ['$'],
#              'Westlake_Southern': ['$$'],
#              'Westlake_Dive Bars': ['$$'],
#              'Westlake_Poke': ['$$'],
#              'Westlake_Vegan': ['$'],
#              'Culver City_Vegan': ['$', '$$', '$$$'],
#              'Culver City_American (New)': ['$$', '$$$$'],
#              'Culver City_Cafes': ['$', '$$'],
#              'Culver City_Breakfast & Brunch': ['$', '$$'],
#              'Culver City_Juice Bars & Smoothies': ['$$'],
#              'Culver City_Burgers': ['$$'],
#              'Culver City_Sandwiches': ['$$'],
#              'Culver City_Diners': ['$$'],
#              'Culver City_Salad': ['$', '$$'],
#              'Culver City_Seafood': ['$$', '$$$', '$$$$'],
#              'Culver City_Gastropubs': ['$$'],
#              'Culver City_American (Traditional)': ['$$', '$$$', '$$$$'],
#              'Culver City_Ethiopian': ['$$'],
#              'Culver City_Karaoke': ['$$'],
#              'Culver City_Cocktail Bars': ['$$', '$$$'],
#              'Culver City_Barbeque': ['$$'],
#              'Culver City_Wine Bars': ['$$', '$$$'],
#              'Culver City_Steakhouses': ['$$$$'],
#              'Culver City_Argentine': ['$', '$$'],
#              'Culver City_Empanadas': ['$'],
#              'Culver City_Bakeries': ['$$'],
#              'Culver City_Asian Fusion': ['$', '$$'],
#              'Culver City_Japanese': ['$', '$$', '$$$'],
#              'Culver City_Sushi Bars': ['$$', '$$$'],
#              'Culver City_Korean': ['$$'],
#              'Culver City_Food Trucks': ['$$'],
#              'Culver City_Brazilian': ['$$'],
#              'Culver City_Buffets': ['$$'],
#              'Culver City_Pizza': ['$', '$$'],
#              'Culver City_Chicken Shop': ['$$'],
#              'Culver City_Vegetarian': ['$', '$$'],
#              'Culver City_Burmese': ['$$'],
#              'Culver City_Indian': ['$', '$$'],
#              'Culver City_Halal': ['$$'],
#              'Culver City_French': ['$$'],
#              'Culver City_Donuts': ['$'],
#              'Culver City_Coffee & Tea': ['$', '$$'],
#              'Culver City_Caribbean': ['$$'],
#              'Culver City_Chinese': ['$$'],
#              'Culver City_Bubble Tea': ['$$'],
#              'Culver City_Noodles': ['$$'],
#              'Culver City_Italian': ['$', '$$'],
#              'Culver City_Delis': ['$', '$$'],
#              'Culver City_Seafood Markets': ['$$'],
#              'Culver City_Fish & Chips': ['$$'],
#              'Culver City_Tacos': ['$', '$$'],
#              'Culver City_Cupcakes': ['$$'],
#              'Culver City_Gluten-Free': ['$$', '$$$'],
#              'Culver City_Greek': ['$$'],
#              'Culver City_Mediterranean': ['$$'],
#              'Culver City_Pakistani': ['$$'],
#              'Culver City_Sardinian': ['$$'],
#              'Culver City_Bars': ['$$'],
#              'Culver City_Ramen': ['$$'],
#              'Culver City_Izakaya': ['$$'],
#              'Culver City_Tapas/Small Plates': ['$$'],
#              'Culver City_Poke': ['$$'],
#              'Culver City_Chicken Wings': ['$$'],
#              'Culver City_Peruvian': ['$$'],
#              'Culver City_Latin American': ['$$'],
#              'Culver City_Middle Eastern': ['$$'],
#              'Culver City_Mexican': ['$', '$$'],
#              'Culver City_Scandinavian': ['$$'],
#              'Culver City_Thai': ['$$'],
#              'Culver City_Soup': ['$$'],
#              'Culver City_Brewpubs': ['$$'],
#              'Pasadena_Barbeque': ['$$', '$$$'],
#              'Pasadena_American (New)': ['$$', '$$$'],
#              'Pasadena_Cocktail Bars': ['$', '$$', '$$$', '$$$$'],
#              'Pasadena_Burgers': ['$', '$$'],
#              'Pasadena_Bars': ['$$', '$$$'],
#              'Pasadena_Sandwiches': ['$', '$$'],
#              'Pasadena_Salad': ['$$'],
#              'Pasadena_Hot Dogs': ['$$'],
#              'Pasadena_Pizza': ['$', '$$'],
#              'Pasadena_Breakfast & Brunch': ['$', '$$', '$$$'],
#              'Pasadena_Vegetarian': ['$', '$$'],
#              'Pasadena_Vegan': ['$', '$$'],
#              'Pasadena_Gastropubs': ['$$'],
#              'Pasadena_Wine Bars': ['$$', '$$$', '$$$$'],
#              'Pasadena_Coffee & Tea': ['$', '$$'],
#              'Pasadena_Cafes': ['$', '$$'],
#              'Pasadena_Seafood': ['$', '$$', '$$$', '$$$$'],
#              'Pasadena_Steakhouses': ['$$', '$$$', '$$$$'],
#              'Pasadena_Sushi Bars': ['$$', '$$$'],
#              'Pasadena_Sports Bars': ['$$'],
#              'Pasadena_Chicken Shop': ['$', '$$'],
#              'Pasadena_American (Traditional)': ['$$', '$$$'],
#              'Pasadena_Waffles': ['$', '$$'],
#              'Pasadena_Diners': ['$$'],
#              'Pasadena_Comfort Food': ['$$', '$$$'],
#              'Pasadena_Whiskey Bars': ['$$', '$$$$'],
#              'Pasadena_Pubs': ['$$'],
#              'Pasadena_Argentine': ['$$$'],
#              'Pasadena_Italian': ['$', '$$', '$$$'],
#              'Pasadena_Armenian': ['$'],
#              'Pasadena_Middle Eastern': ['$', '$$'],
#              'Pasadena_Vietnamese': ['$', '$$'],
#              'Pasadena_Asian Fusion': ['$', '$$', '$$$', '$$$$'],
#              'Pasadena_Thai': ['$', '$$'],
#              'Pasadena_Japanese': ['$$', '$$$'],
#              'Pasadena_Chinese': ['$', '$$'],
#              'Pasadena_Korean': ['$$', '$$$'],
#              'Pasadena_Food Trucks': ['$', '$$'],
#              'Pasadena_Desserts': ['$', '$$'],
#              'Pasadena_Basque': ['$$$'],
#              'Pasadena_Acai Bowls': ['$$'],
#              'Pasadena_Brazilian': ['$$'],
#              'Pasadena_Juice Bars & Smoothies': ['$', '$$'],
#              'Pasadena_British': ['$$'],
#              'Pasadena_Fish & Chips': ['$$'],
#              'Pasadena_Mexican': ['$', '$$', '$$$'],
#              'Pasadena_Bubble Tea': ['$', '$$'],
#              'Pasadena_Bakeries': ['$', '$$'],
#              'Pasadena_Cajun/Creole': ['$'],
#              'Pasadena_Chicken Wings': ['$', '$$'],
#              'Pasadena_Noodles': ['$$'],
#              'Pasadena_Soup': ['$$'],
#              'Pasadena_Hot Pot': ['$$'],
#              'Pasadena_Dim Sum': ['$$'],
#              'Pasadena_Taiwanese': ['$', '$$'],
#              'Pasadena_Creperies': ['$$'],
#              'Pasadena_Cantonese': ['$$'],
#              'Pasadena_Japanese Curry': ['$$'],
#              'Pasadena_Delis': ['$', '$$'],
#              'Pasadena_Dinner Theater': ['$$'],
#              'Pasadena_Indonesian': ['$', '$$', '$$$'],
#              'Pasadena_Pan Asian': ['$$$'],
#              'Pasadena_Filipino': ['$', '$$$'],
#              'Pasadena_French': ['$$$'],
#              'Pasadena_Gluten-Free': ['$'],
#              'Pasadena_Mediterranean': ['$', '$$'],
#              'Pasadena_Persian/Iranian': ['$$'],
#              'Pasadena_Halal': ['$$'],
#              'Pasadena_Himalayan/Nepalese': ['$$'],
#              'Pasadena_Indian': ['$', '$$'],
#              'Pasadena_Singaporean': ['$', '$$'],
#              'Pasadena_Ramen': ['$$', '$$$'],
#              'Pasadena_Izakaya': ['$$$'],
#              'Pasadena_Lebanese': ['$$'],
#              'Pasadena_Kebab': ['$$'],
#              'Pasadena_Shaved Ice': ['$', '$$'],
#              'Pasadena_Venezuelan': ['$$'],
#              'Pasadena_Empanadas': ['$$'],
#              'Pasadena_Latin American': ['$$'],
#              'Pasadena_Peruvian': ['$$'],
#              'Pasadena_Salvadoran': ['$'],
#              'Pasadena_Live/Raw Food': ['$$'],
#              'Pasadena_Tacos': ['$', '$$'],
#              'Pasadena_Fast Food': ['$'],
#              'Pasadena_Pop-Up Restaurants': ['$'],
#              'Pasadena_Ice Cream & Frozen Yogurt': ['$$'],
#              'Pasadena_Poke': ['$$'],
#              'Pasadena_Tapas/Small Plates': ['$$'],
#              'Pasadena_Southern': ['$$'],
#              'Pasadena_Hawaiian': ['$$'],
#              'Pasadena_Greek': ['$'],
#              'Pasadena_Food Stands': ['$'],
#              'Pasadena_New Mexican Cuisine': ['$$'],
#              'Pasadena_Donuts': ['$'],
#              'Sherman Oaks_American (New)': ['$$', '$$$'],
#              'Sherman Oaks_Seafood': ['$$', '$$$'],
#              'Sherman Oaks_Soul Food': ['$$'],
#              'Sherman Oaks_Vegan': ['$$'],
#              'Sherman Oaks_Wine Bars': ['$$', '$$$'],
#              'Sherman Oaks_Cocktail Bars': ['$$', '$$$'],
#              'Sherman Oaks_Breakfast & Brunch': ['$', '$$'],
#              'Sherman Oaks_Modern European': ['$$'],
#              'Sherman Oaks_American (Traditional)': ['$$'],
#              'Sherman Oaks_Bars': ['$$'],
#              'Sherman Oaks_Cafes': ['$$'],
#              'Sherman Oaks_Gastropubs': ['$$'],
#              'Sherman Oaks_Burgers': ['$', '$$'],
#              'Sherman Oaks_Pizza': ['$', '$$', '$$$'],
#              'Sherman Oaks_Italian': ['$', '$$'],
#              'Sherman Oaks_Japanese': ['$$'],
#              'Sherman Oaks_Asian Fusion': ['$', '$$'],
#              'Sherman Oaks_Noodles': ['$$'],
#              'Sherman Oaks_Barbeque': ['$', '$$'],
#              'Sherman Oaks_Bubble Tea': ['$', '$$'],
#              'Sherman Oaks_Vietnamese': ['$$'],
#              'Sherman Oaks_Thai': ['$', '$$'],
#              'Sherman Oaks_Chinese': ['$', '$$'],
#              'Sherman Oaks_Food Trucks': ['$', '$$'],
#              'Sherman Oaks_Salad': ['$', '$$', '$$$'],
#              'Sherman Oaks_Acai Bowls': ['$$'],
#              'Sherman Oaks_Brazilian': ['$$'],
#              'Sherman Oaks_Juice Bars & Smoothies': ['$', '$$'],
#              'Sherman Oaks_Kosher': ['$$'],
#              'Sherman Oaks_Sandwiches': ['$', '$$'],
#              'Sherman Oaks_Portuguese': ['$$'],
#              'Sherman Oaks_Desserts': ['$$', '$$$'],
#              'Sherman Oaks_Cajun/Creole': ['$$'],
#              'Sherman Oaks_Southern': ['$$'],
#              'Sherman Oaks_Soup': ['$$'],
#              'Sherman Oaks_Delis': ['$$'],
#              'Sherman Oaks_Fish & Chips': ['$$'],
#              'Sherman Oaks_French': ['$$', '$$$'],
#              'Sherman Oaks_Steakhouses': ['$$$'],
#              'Sherman Oaks_Pubs': ['$$'],
#              'Sherman Oaks_Sports Bars': ['$$'],
#              'Sherman Oaks_Coffee & Tea': ['$', '$$'],
#              'Sherman Oaks_Gluten-Free': ['$$'],
#              'Sherman Oaks_Greek': ['$$'],
#              'Sherman Oaks_Mediterranean': ['$', '$$', '$$$'],
#              'Sherman Oaks_Wraps': ['$$'],
#              'Sherman Oaks_Chicken Shop': ['$$'],
#              'Sherman Oaks_Halal': ['$$'],
#              'Sherman Oaks_Hawaiian': ['$$'],
#              'Sherman Oaks_Poke': ['$$'],
#              'Sherman Oaks_Fast Food': ['$$'],
#              'Sherman Oaks_Indian': ['$$'],
#              'Sherman Oaks_Sicilian': ['$$$'],
#              'Sherman Oaks_Ramen': ['$$'],
#              'Sherman Oaks_Sushi Bars': ['$$', '$$$$'],
#              'Sherman Oaks_Falafel': ['$$'],
#              'Sherman Oaks_Middle Eastern': ['$$', '$$$'],
#              'Sherman Oaks_Latin American': ['$$'],
#              'Sherman Oaks_Mexican': ['$', '$$', '$$$'],
#              'Sherman Oaks_Vegetarian': ['$$'],
#              'Sherman Oaks_Tacos': ['$'],
#              'Sherman Oaks_Donuts': ['$'],
#              'Sherman Oaks_Seafood Markets': ['$$'],
#              'Toluca Lake_American (New)': ['$$'],
#              'Toluca Lake_Asian Fusion': ['$$'],
#              'Toluca Lake_Coffee & Tea': ['$$'],
#              'Toluca Lake_Breakfast & Brunch': ['$$'],
#              'Toluca Lake_Thai': ['$$'],
#              'Toluca Lake_Whiskey Bars': ['$$'],
#              'Toluca Lake_Cocktail Bars': ['$$'],
#              'Toluca Lake_American (Traditional)': ['$$'],
#              'Toluca Lake_Bakeries': ['$$'],
#              'Toluca Lake_Soup': ['$$'],
#              'Toluca Lake_Argentine': ['$$'],
#              'Toluca Lake_Steakhouses': ['$$'],
#              'Toluca Lake_Italian': ['$$'],
#              'Toluca Lake_Vegan': ['$$'],
#              'Toluca Lake_Burgers': ['$$'],
#              'Toluca Lake_Delis': ['$$'],
#              'Toluca Lake_Seafood': ['$$'],
#              'Toluca Lake_Pizza': ['$$'],
#              'Toluca Lake_Bars': ['$$'],
#              'Toluca Lake_Sushi Bars': ['$$', '$$$'],
#              'Toluca Lake_Japanese': ['$$', '$$$'],
#              'Toluca Lake_Tacos': ['$', '$$'],
#              'Toluca Lake_Food Trucks': ['$'],
#              'Toluca Lake_Desserts': ['$$'],
#              'Toluca Lake_Mexican': ['$$'],
#              'Toluca Lake_Vietnamese': ['$$'],
#              'Toluca Lake_Noodles': ['$$'],
#              'Toluca Lake_Sandwiches': ['$$'],
#              'Toluca Lake_Juice Bars & Smoothies': ['$$'],
#              'Toluca Lake_Salad': ['$$'],
#              'Downtown_Tapas/Small Plates': ['$', '$$', '$$$'],
#              'Downtown_Bars': ['$$', '$$$', '$$$$'],
#              'Downtown_American (New)': ['$', '$$', '$$$', '$$$$'],
#              'Downtown_Sandwiches': ['$', '$$'],
#              'Downtown_Coffee & Tea': ['$', '$$'],
#              'Downtown_Salad': ['$', '$$'],
#              'Downtown_Wraps': ['$$'],
#              'Downtown_Burgers': ['$', '$$'],
#              'Downtown_Cocktail Bars': ['$$', '$$$', '$$$$'],
#              'Downtown_Breakfast & Brunch': ['$', '$$', '$$$'],
#              'Downtown_Breweries': ['$$'],
#              'Downtown_Pubs': ['$$'],
#              'Downtown_Cafes': ['$', '$$'],
#              'Downtown_Comfort Food': ['$', '$$'],
#              'Downtown_Indian': ['$$'],
#              'Downtown_Steakhouses': ['$$', '$$$', '$$$$'],
#              'Downtown_Korean': ['$', '$$'],
#              'Downtown_Gastropubs': ['$$'],
#              'Downtown_Irish': ['$$'],
#              'Downtown_Soul Food': ['$$'],
#              'Downtown_American (Traditional)': ['$', '$$', '$$$$'],
#              'Downtown_Fast Food': ['$', '$$'],
#              'Downtown_Food Trucks': ['$', '$$'],
#              'Downtown_Italian': ['$', '$$', '$$$', '$$$$'],
#              'Downtown_Mexican': ['$', '$$', '$$$'],
#              'Downtown_Diners': ['$', '$$'],
#              'Downtown_Chicken Shop': ['$', '$$'],
#              'Downtown_Halal': ['$', '$$'],
#              'Downtown_Seafood': ['$', '$$', '$$$', '$$$$'],
#              'Downtown_Chinese': ['$$'],
#              'Downtown_Cajun/Creole': ['$$'],
#              'Downtown_Brewpubs': ['$$'],
#              'Downtown_Chicken Wings': ['$', '$$'],
#              'Downtown_Argentine': ['$$'],
#              'Downtown_Barbeque': ['$', '$$', '$$$'],
#              'Downtown_Mediterranean': ['$', '$$', '$$$'],
#              'Downtown_Armenian': ['$', '$$'],
#              'Downtown_Persian/Iranian': ['$', '$$'],
#              'Downtown_Japanese': ['$', '$$', '$$$', '$$$$'],
#              'Downtown_Noodles': ['$', '$$'],
#              'Downtown_Asian Fusion': ['$', '$$', '$$$'],
#              'Downtown_Hawaiian': ['$$'],
#              'Downtown_Vietnamese': ['$', '$$'],
#              'Downtown_Sushi Bars': ['$', '$$', '$$$', '$$$$'],
#              'Downtown_Thai': ['$$'],
#              'Downtown_Pop-Up Restaurants': ['$', '$$'],
#              'Downtown_Cantonese': ['$$'],
#              'Downtown_French': ['$$', '$$$', '$$$$'],
#              'Downtown_Brasseries': ['$$$$'],
#              'Downtown_Brazilian': ['$$', '$$$'],
#              'Downtown_Vegan': ['$', '$$', '$$$'],
#              'Downtown_Delis': ['$', '$$'],
#              'Downtown_Bakeries': ['$', '$$'],
#              'Downtown_Vegetarian': ['$', '$$'],
#              'Downtown_Pizza': ['$', '$$', '$$$'],
#              'Downtown_Puerto Rican': ['$'],
#              'Downtown_Food Stands': ['$'],
#              'Downtown_Creperies': ['$$'],
#              'Downtown_Cheesesteaks': ['$$'],
#              'Downtown_Wine Bars': ['$$', '$$$', '$$$$'],
#              'Downtown_Modern European': ['$$', '$$$'],
#              'Downtown_Hot Dogs': ['$', '$$'],
#              'Downtown_German': ['$$'],
#              'Downtown_Gluten-Free': ['$', '$$', '$$$'],
#              'Downtown_Juice Bars & Smoothies': ['$$'],
#              'Downtown_Middle Eastern': ['$', '$$', '$$$'],
#              'Downtown_Pakistani': ['$$'],
#              'Downtown_Hot Pot': ['$$'],
#              'Downtown_Desserts': ['$', '$$', '$$$'],
#              'Downtown_Pasta Shops': ['$$$'],
#              'Downtown_Izakaya': ['$$', '$$$'],
#              'Downtown_Taiwanese': ['$$', '$$$$'],
#              'Downtown_Ramen': ['$$'],
#              'Downtown_Japanese Curry': ['$$'],
#              'Downtown_Live/Raw Food': ['$$', '$$$'],
#              'Downtown_Shaved Ice': ['$$'],
#              'Downtown_Seafood Markets': ['$$'],
#              'Downtown_Teppanyaki': ['$$'],
#              'Downtown_Kebab': ['$', '$$'],
#              'Downtown_Ice Cream & Frozen Yogurt': ['$'],
#              'Downtown_Kosher': ['$$'],
#              'Downtown_Latin American': ['$', '$$$'],
#              'Downtown_Salvadoran': ['$'],
#              'Downtown_Falafel': ['$$'],
#              'Downtown_Peruvian': ['$', '$$', '$$$'],
#              'Downtown_Street Vendors': ['$', '$$'],
#              'Downtown_Tacos': ['$', '$$'],
#              'Downtown_Southern': ['$$'],
#              'Downtown_New Mexican Cuisine': ['$$'],
#              'Downtown_Tex-Mex': ['$$'],
#              'Downtown_Portuguese': ['$$$'],
#              'Downtown_Donuts': ['$$'],
#              'Downtown_Sports Bars': ['$$'],
#              'Downtown_Bubble Tea': ['$$'],
#              'Downtown_Soup': ['$'],
#              'Arlington Heights_Seafood': ['$$'],
#              'Arlington Heights_Latin American': ['$$'],
#              'Arlington Heights_American (New)': ['$$'],
#              'Arlington Heights_Caribbean': ['$$'],
#              'Arlington Heights_Korean': ['$', '$$', '$$$'],
#              'Arlington Heights_Barbeque': ['$$', '$$$'],
#              'Arlington Heights_Cafes': ['$', '$$'],
#              'Arlington Heights_Burgers': ['$'],
#              'Arlington Heights_Sandwiches': ['$', '$$'],
#              'Arlington Heights_Southern': ['$$'],
#              'Arlington Heights_Chicken Shop': ['$$'],
#              'Arlington Heights_Comfort Food': ['$$'],
#              'Arlington Heights_Delis': ['$', '$$'],
#              'Arlington Heights_Italian': ['$$'],
#              'Arlington Heights_Salvadoran': ['$'],
#              'Arlington Heights_Bakeries': ['$'],
#              'Arlington Heights_Noodles': ['$', '$$'],
#              'Arlington Heights_Soup': ['$$'],
#              'Arlington Heights_Mexican': ['$'],
#              'Arlington Heights_Food Stands': ['$'],
#              'Arlington Heights_Salad': ['$'],
#              'Arlington Heights_Pizza': ['$'],
#              'Arlington Heights_Chicken Wings': ['$'],
#              'Beverly Hills_American (New)': ['$$', '$$$', '$$$$'],
#              'Beverly Hills_Asian Fusion': ['$$', '$$$$'],
#              'Beverly Hills_Breakfast & Brunch': ['$', '$$', '$$$', '$$$$'],
#              'Beverly Hills_Cocktail Bars': ['$$', '$$$', '$$$$'],
#              'Beverly Hills_Seafood': ['$$', '$$$', '$$$$'],
#              'Beverly Hills_Steakhouses': ['$$$', '$$$$'],
#              'Beverly Hills_Bars': ['$$', '$$$'],
#              'Beverly Hills_Italian': ['$$', '$$$'],
#              'Beverly Hills_Sushi Bars': ['$$', '$$$', '$$$$'],
#              'Beverly Hills_Mediterranean': ['$$', '$$$'],
#              'Beverly Hills_Burgers': ['$', '$$'],
#              'Beverly Hills_Tapas/Small Plates': ['$$', '$$$'],
#              'Beverly Hills_Modern European': ['$$$', '$$$$'],
#              'Beverly Hills_American (Traditional)': ['$', '$$', '$$$'],
#              'Beverly Hills_Diners': ['$$$'],
#              'Beverly Hills_Japanese': ['$$', '$$$', '$$$$'],
#              'Beverly Hills_Barbeque': ['$$$', '$$$$'],
#              'Beverly Hills_Korean': ['$$$'],
#              'Beverly Hills_Brazilian': ['$$$$'],
#              'Beverly Hills_Coffee & Tea': ['$', '$$'],
#              'Beverly Hills_Sandwiches': ['$', '$$'],
#              'Beverly Hills_Cafes': ['$', '$$'],
#              'Beverly Hills_Desserts': ['$$'],
#              'Beverly Hills_Creperies': ['$$'],
#              'Beverly Hills_Ice Cream & Frozen Yogurt': ['$$'],
#              'Beverly Hills_Bakeries': ['$$'],
#              'Beverly Hills_French': ['$$', '$$$'],
#              'Beverly Hills_Chinese': ['$$', '$$$'],
#              'Beverly Hills_Dim Sum': ['$$'],
#              'Beverly Hills_Cantonese': ['$$'],
#              'Beverly Hills_Delis': ['$', '$$', '$$$$'],
#              'Beverly Hills_Gelato': ['$$'],
#              'Beverly Hills_Gluten-Free': ['$$'],
#              'Beverly Hills_Pasta Shops': ['$$'],
#              'Beverly Hills_Greek': ['$$$'],
#              'Beverly Hills_Persian/Iranian': ['$$'],
#              'Beverly Hills_Halal': ['$$'],
#              'Beverly Hills_Hot Pot': ['$$$$'],
#              'Beverly Hills_Indian': ['$$', '$$$'],
#              'Beverly Hills_Pizza': ['$$'],
#              'Beverly Hills_Salad': ['$$'],
#              'Beverly Hills_Noodles': ['$$'],
#              'Beverly Hills_Ramen': ['$$'],
#              'Beverly Hills_Thai': ['$$'],
#              'Beverly Hills_Kosher': ['$$'],
#              'Beverly Hills_Tacos': ['$$'],
#              'Beverly Hills_Mexican': ['$$', '$$$$'],
#              'Beverly Hills_Moroccan': ['$$$'],
#              'Beverly Hills_Wine Bars': ['$$$'],
#              'Beverly Hills_Chicken Wings': ['$$'],
#              'Beverly Hills_Vegan': ['$$'],
#              'Beverly Hills_Vegetarian': ['$$'],
#              'Beverly Hills_Juice Bars & Smoothies': ['$$'],
#              'Glendale_Hookah Bars': ['$$'],
#              'Glendale_American (New)': ['$$'],
#              'Glendale_Cocktail Bars': ['$$', '$$$$'],
#              'Glendale_Mediterranean': ['$', '$$', '$$$'],
#              'Glendale_Seafood': ['$', '$$', '$$$'],
#              'Glendale_Wine Bars': ['$$', '$$$', '$$$$'],
#              'Glendale_Breakfast & Brunch': ['$', '$$'],
#              'Glendale_Coffee & Tea': ['$', '$$'],
#              'Glendale_Gastropubs': ['$$'],
#              'Glendale_Pubs': ['$$'],
#              'Glendale_Burgers': ['$', '$$'],
#              'Glendale_Sandwiches': ['$', '$$'],
#              'Glendale_Cajun/Creole': ['$$'],
#              'Glendale_Persian/Iranian': ['$', '$$'],
#              'Glendale_American (Traditional)': ['$', '$$'],
#              'Glendale_Chicken Shop': ['$$'],
#              'Glendale_Desserts': ['$', '$$'],
#              'Glendale_Diners': ['$$'],
#              'Glendale_Halal': ['$', '$$'],
#              'Glendale_Sports Bars': ['$$'],
#              'Glendale_Chicken Wings': ['$$'],
#              'Glendale_Barbeque': ['$$'],
#              'Glendale_Fast Food': ['$', '$$'],
#              'Glendale_Mexican': ['$', '$$'],
#              'Glendale_Argentine': ['$', '$$'],
#              'Glendale_Empanadas': ['$'],
#              'Glendale_Italian': ['$', '$$'],
#              'Glendale_Armenian': ['$', '$$', '$$$'],
#              'Glendale_Kebab': ['$$'],
#              'Glendale_Comfort Food': ['$$'],
#              'Glendale_Bakeries': ['$', '$$'],
#              'Glendale_Soup': ['$', '$$'],
#              'Glendale_Middle Eastern': ['$', '$$'],
#              'Glendale_Russian': ['$$'],
#              'Glendale_Georgian': ['$$'],
#              'Glendale_Seafood Markets': ['$$'],
#              'Glendale_Pizza': ['$', '$$'],
#              'Glendale_Delis': ['$', '$$'],
#              'Glendale_Salad': ['$', '$$', '$$$'],
#              'Glendale_Hawaiian': ['$$'],
#              'Glendale_Asian Fusion': ['$', '$$'],
#              'Glendale_Thai': ['$', '$$'],
#              'Glendale_Poke': ['$$'],
#              'Glendale_Sushi Bars': ['$$', '$$$$'],
#              'Glendale_Japanese': ['$$', '$$$$'],
#              'Glendale_Filipino': ['$', '$$'],
#              'Glendale_Brazilian': ['$$'],
#              'Glendale_Cafes': ['$', '$$'],
#              'Glendale_Tacos': ['$', '$$'],
#              'Glendale_Waffles': ['$$'],
#              'Glendale_Shanghainese': ['$$'],
#              'Glendale_Dim Sum': ['$$'],
#              'Glendale_Taiwanese': ['$$'],
#              'Glendale_Chinese': ['$', '$$'],
#              'Glendale_Cuban': ['$$'],
#              'Glendale_German': ['$$'],
#              'Glendale_Fish & Chips': ['$$'],
#              'Glendale_French': ['$', '$$'],
#              'Glendale_Vegan': ['$', '$$'],
#              'Glendale_Gluten-Free': ['$$'],
#              'Glendale_Greek': ['$', '$$'],
#              'Glendale_Indian': ['$$'],
#              'Glendale_Hot Pot': ['$$'],
#              'Glendale_Vegetarian': ['$', '$$'],
#              'Glendale_Pasta Shops': ['$$'],
#              'Glendale_Japanese Curry': ['$$'],
#              'Glendale_Ramen': ['$$'],
#              'Glendale_Izakaya': ['$$'],
#              'Glendale_Vietnamese': ['$$'],
#              'Glendale_Korean': ['$', '$$'],
#              'Glendale_Teppanyaki': ['$$$'],
#              'Glendale_Steakhouses': ['$$', '$$$', '$$$$'],
#              'Glendale_Conveyor Belt Sushi': ['$$'],
#              'Glendale_Noodles': ['$$'],
#              'Glendale_Bubble Tea': ['$'],
#              'Glendale_Venezuelan': ['$$'],
#              'Glendale_Latin American': ['$', '$$'],
#              'Glendale_Peruvian': ['$$'],
#              'Glendale_Lebanese': ['$', '$$'],
#              'Glendale_Modern European': ['$$$'],
#              'Glendale_Food Stands': ['$'],
#              'Glendale_Bars': ['$$'],
#              'Glendale_Ice Cream & Frozen Yogurt': ['$'],
#              'Glendale_Juice Bars & Smoothies': ['$', '$$'],
#              'Glendale_Hot Dogs': ['$'],
#              'Glendale_Donuts': ['$'],
#              'Glendale_Tiki Bars': ['$$'],
#              'Glendale_Spanish': ['$$$'],
#              'Glendale_Tapas Bars': ['$$$'],
#              'East Hollywood_Cheesesteaks': ['$$'],
#              'East Hollywood_Sandwiches': ['$', '$$'],
#              'East Hollywood_American (New)': ['$$'],
#              'East Hollywood_Bakeries': ['$', '$$'],
#              'East Hollywood_Breakfast & Brunch': ['$', '$$'],
#              'East Hollywood_Salad': ['$', '$$'],
#              'East Hollywood_Wine Bars': ['$$'],
#              'East Hollywood_Argentine': ['$$'],
#              'East Hollywood_Empanadas': ['$$'],
#              'East Hollywood_Armenian': ['$', '$$', '$$$'],
#              'East Hollywood_Lebanese': ['$$', '$$$'],
#              'East Hollywood_Kebab': ['$'],
#              'East Hollywood_Filipino': ['$', '$$'],
#              'East Hollywood_Asian Fusion': ['$', '$$'],
#              'East Hollywood_Burgers': ['$', '$$'],
#              'East Hollywood_Sushi Bars': ['$$'],
#              'East Hollywood_Japanese': ['$$'],
#              'East Hollywood_Thai': ['$', '$$'],
#              'East Hollywood_Cocktail Bars': ['$$', '$$$'],
#              'East Hollywood_Barbeque': ['$$'],
#              'East Hollywood_Korean': ['$$'],
#              'East Hollywood_Buffets': ['$$'],
#              'East Hollywood_Indian': ['$$'],
#              'East Hollywood_Halal': ['$$'],
#              'East Hollywood_Pizza': ['$', '$$'],
#              'East Hollywood_Italian': ['$', '$$'],
#              'East Hollywood_Coffee & Tea': ['$', '$$', '$$$'],
#              'East Hollywood_Cafes': ['$', '$$'],
#              'East Hollywood_Hookah Bars': ['$$'],
#              'East Hollywood_Cajun/Creole': ['$$'],
#              'East Hollywood_Seafood': ['$', '$$'],
#              'East Hollywood_Chinese': ['$'],
#              'East Hollywood_Comfort Food': ['$$'],
#              'East Hollywood_Soup': ['$', '$$'],
#              'East Hollywood_Vietnamese': ['$$'],
#              'East Hollywood_Delis': ['$'],
#              'East Hollywood_Mediterranean': ['$'],
#              'East Hollywood_Wraps': ['$'],
#              'East Hollywood_American (Traditional)': ['$$'],
#              'East Hollywood_Fish & Chips': ['$$'],
#              'East Hollywood_Chicken Shop': ['$$'],
#              'East Hollywood_Hot Pot': ['$$'],
#              'East Hollywood_Desserts': ['$$'],
#              'East Hollywood_Vegan': ['$$'],
#              'East Hollywood_Ramen': ['$$'],
#              'East Hollywood_Mexican': ['$', '$$'],
#              'East Hollywood_Salvadoran': ['$', '$$'],
#              'East Hollywood_Latin American': ['$', '$$'],
#              'East Hollywood_Juice Bars & Smoothies': ['$$'],
#              'East Hollywood_Live/Raw Food': ['$$'],
#              'East Hollywood_Falafel': ['$'],
#              'East Hollywood_Middle Eastern': ['$', '$$$'],
#              'East Hollywood_Vegetarian': ['$'],
#              'East Hollywood_Tex-Mex': ['$'],
#              'East Hollywood_Tacos': ['$'],
#              'East Hollywood_Noodles': ['$', '$$'],
#              'Larchmont_American (New)': ['$$', '$$$$'],
#              'Larchmont_Cocktail Bars': ['$$', '$$$'],
#              'Larchmont_Argentine': ['$$'],
#              'Larchmont_Empanadas': ['$$'],
#              'Larchmont_Sandwiches': ['$', '$$'],
#              'Larchmont_Korean': ['$$'],
#              'Larchmont_Barbeque': ['$$'],
#              'Larchmont_Coffee & Tea': ['$', '$$'],
#              'Larchmont_Cafes': ['$', '$$'],
#              'Larchmont_Breakfast & Brunch': ['$$'],
#              'Larchmont_Vegan': ['$$'],
#              'Larchmont_Vegetarian': ['$$'],
#              'Larchmont_Italian': ['$$', '$$$'],
#              'Larchmont_Pizza': ['$', '$$$'],
#              'Larchmont_Wine Bars': ['$$'],
#              'Larchmont_Ramen': ['$$'],
#              'Larchmont_Noodles': ['$$'],
#              'Larchmont_Sushi Bars': ['$$'],
#              'Larchmont_Mexican': ['$$'],
#              'Larchmont_Seafood': ['$$'],
#              'Larchmont_Peruvian': ['$$'],
#              'Larchmont_Salad': ['$'],
#              'Larchmont_Chicken Wings': ['$'],
#              'Studio City_American (New)': ['$$', '$$$'],
#              'Studio City_Middle Eastern': ['$$', '$$$'],
#              'Studio City_Mediterranean': ['$$', '$$$'],
#              'Studio City_Gastropubs': ['$$'],
#              'Studio City_Breakfast & Brunch': ['$', '$$'],
#              'Studio City_Cocktail Bars': ['$$', '$$$'],
#              'Studio City_Hookah Bars': ['$$', '$$$'],
#              'Studio City_Sandwiches': ['$', '$$'],
#              'Studio City_Salad': ['$$'],
#              'Studio City_Burgers': ['$', '$$'],
#              'Studio City_Cafes': ['$', '$$'],
#              'Studio City_American (Traditional)': ['$', '$$'],
#              'Studio City_Fast Food': ['$$'],
#              'Studio City_Coffee & Tea': ['$', '$$'],
#              'Studio City_Argentine': ['$$'],
#              'Studio City_Steakhouses': ['$$'],
#              'Studio City_Seafood': ['$$'],
#              'Studio City_Armenian': ['$$'],
#              'Studio City_Lebanese': ['$$'],
#              'Studio City_Asian Fusion': ['$$'],
#              'Studio City_Thai': ['$$'],
#              'Studio City_Vietnamese': ['$', '$$'],
#              ...})

# %%
#save the neigh_cuisine_prices_dict
with open(fpath + 'neigh_cuisine_prices_dict.pkl','wb') as f:
    pickle.dump(neigh_cuisine_prices_dict,f)
